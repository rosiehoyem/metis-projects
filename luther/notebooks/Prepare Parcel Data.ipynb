# %%
# Python 2 & 3 Compatibility
from __future__ import print_function, division

# Necessary imports
import pandas as pd
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
import patsy
import seaborn as sns
from seaborn import plt
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import RidgeCV

# %matplotlib inline

# %%
from dbfread import DBF

# %%
table = DBF('../data/raw/hennepin_county_metrogis_parcels/hennepin_county_metrogis_parcels.dbf', load=True, raw=True)

# %%
cols = table.field_names
cols
# Out:
# ['COUNTY_ID',
#  'PIN',
#  'BLDG_NUM',
#  'PREFIX_DIR',
#  'PREFIXTYPE',
#  'STREETNAME',
#  'STREETTYPE',
#  'SUFFIX_DIR',
#  'UNIT_INFO',
#  'CITY',
#  'CITY_USPS',
#  'ZIP',
#  'ZIP4',
#  'PLAT_NAME',
#  'BLOCK',
#  'LOT',
#  'ACRES_POLY',
#  'ACRES_DEED',
#  'USE1_DESC',
#  'USE2_DESC',
#  'USE3_DESC',
#  'USE4_DESC',
#  'MULTI_USES',
#  'LANDMARK',
#  'OWNER_NAME',
#  'OWNER_MORE',
#  'OWN_ADD_L1',
#  'OWN_ADD_L2',
#  'OWN_ADD_L3',
#  'TAX_NAME',
#  'TAX_ADD_L1',
#  'TAX_ADD_L2',
#  'TAX_ADD_L3',
#  'HOMESTEAD',
#  'EMV_LAND',
#  'EMV_BLDG',
#  'EMV_TOTAL',
#  'TAX_CAPAC',
#  'TOTAL_TAX',
#  'SPEC_ASSES',
#  'TAX_EXEMPT',
#  'XUSE1_DESC',
#  'XUSE2_DESC',
#  'XUSE3_DESC',
#  'XUSE4_DESC',
#  'DWELL_TYPE',
#  'HOME_STYLE',
#  'FIN_SQ_FT',
#  'GARAGE',
#  'GARAGESQFT',
#  'BASEMENT',
#  'HEATING',
#  'COOLING',
#  'YEAR_BUILT',
#  'NUM_UNITS',
#  'SALE_DATE',
#  'SALE_VALUE',
#  'SCHOOL_DST',
#  'WSHD_DIST',
#  'GREEN_ACRE',
#  'OPEN_SPACE',
#  'AG_PRESERV',
#  'AGPRE_ENRD',
#  'AGPRE_EXPD',
#  'PARC_CODE',
#  'Shape_area',
#  'Shape_len']

# %%
df = pd.DataFrame(table.records)

# %%
df.sample(5)
# Out:
#        COUNTY_ID                   PIN       BLDG_NUM PREFIX_DIR PREFIXTYPE  \
# 192608    b'053'  b'053-3011922410056'  b'7102      '      b'  '  b'      '
# 20117     b'053'  b'053-2802924410601'  b'52        '      b'  '  b'      '
# 309456    b'053'  b'053-0602824440102'  b'3750      '      b'  '  b'      '
# 201688    b'053'  b'053-2611922120038'  b'76        '      b'  '  b'      '
# 213156    b'053'  b'053-1811922130017'  b'18053     '      b'  '  b'      '
#
#                                          STREETNAME STREETTYPE SUFFIX_DIR  \
# 192608  b'OLIVE LA N                              '    b'    '      b'  '
# 20117   b'GROVELAND TER                           '    b'    '      b'  '
# 309456  b'HUNTINGTON AVE S                        '    b'    '      b'  '
# 201688  b'ADDRESS UNASSIGNED                      '    b'    '      b'  '
# 213156  b'90TH PL N                               '    b'    '      b'  '
#
#               UNIT_INFO                               CITY  \
# 192608  b'            '  b'MAPLE GROVE                   '
# 20117   b'A316        '  b'MINNEAPOLIS                   '
# 309456  b'            '  b'ST. LOUIS PARK                '
# 201688  b'            '  b'MAPLE GROVE                   '
# 213156  b'            '  b'MAPLE GROVE                   '
#
#                  ...           SCHOOL_DST  \
# 192608           ...            b'279   '
# 20117            ...            b'001   '
# 309456           ...            b'283   '
# 201688           ...            b'279   '
# 213156           ...            b'279   '
#
#                                                 WSHD_DIST GREEN_ACRE  \
# 192608  b'Lower Minnesota River                       ...       b'N'
# 20117   b'Middle Mississippi                          ...       b'N'
# 309456  b'Minnehaha Creek                             ...       b'N'
# 201688  b'                                            ...       b'N'
# 213156  b'Lower Minnesota River                       ...       b'N'
#
#        OPEN_SPACE AG_PRESERV   AGPRE_ENRD   AGPRE_EXPD PARC_CODE  \
# 192608       b'N'       b'N'  b'        '  b'        '  b'    0'
# 20117        b'N'       b'N'  b'        '  b'        '  b'    0'
# 309456       b'N'       b'N'  b'        '  b'        '  b'    0'
# 201688       b'N'       b'N'  b'        '  b'        '  b'    0'
# 213156       b'N'       b'N'  b'        '  b'        '  b'    0'
#
#                     Shape_area               Shape_len
# 192608  b' 1.27749839011e+003'  b' 1.51534686669e+002'
# 20117   b' 6.76664192289e+003'  b' 3.83155196280e+002'
# 309456  b' 8.78432493880e+002'  b' 1.25042085119e+002'
# 201688  b' 1.65218755863e+003'  b' 2.20717937983e+002'
# 213156  b' 7.27030556515e+002'  b' 1.15103267059e+002'
#
# [5 rows x 67 columns]

# %%
df.shape
# Out:
# (429570, 67)

# %%
def decode_binary(df, cols):
    decode = lambda x : x.decode('utf-8')
    for col in cols:
        df[col].apply(decode)
        
def decode_string(df, cols):
    decode = lambda x : string(x)
    for col in cols:
        df[col].apply(decode)

# %%
decode_binary(df, cols)
df.head()
# Out:
#   COUNTY_ID                   PIN       BLDG_NUM PREFIX_DIR PREFIXTYPE  \
# 0    b'053'  b'053-0911821410021'  b'54        '      b'  '  b'      '
# 1    b'053'  b'053-1311821120005'  b'4400 1/2  '      b'  '  b'      '
# 2    b'053'  b'053-1311724440113'  b'2325      '      b'  '  b'      '
# 3    b'053'  b'053-2911821440091'  b'28        '      b'  '  b'      '
# 4    b'053'  b'053-0111823440003'  b'80        '      b'  '  b'      '
#
#                                     STREETNAME STREETTYPE SUFFIX_DIR  \
# 0  b'ADDRESS UNASSIGNED                      '    b'    '      b'  '
# 1  b'LYNDALE AVE N                           '    b'    '      b'  '
# 2  b'MONTCLAIR LA                            '    b'    '      b'  '
# 3  b'ADDRESS UNASSIGNED                      '    b'    '      b'  '
# 4  b'ADDRESS UNASSIGNED                      '    b'    '      b'  '
#
#          UNIT_INFO                               CITY           ...            \
# 0  b'            '  b'CRYSTAL                       '           ...
# 1  b'            '  b'MINNEAPOLIS                   '           ...
# 2  b'            '  b'MOUND                         '           ...
# 3  b'            '  b'GOLDEN VALLEY                 '           ...
# 4  b'            '  b'MEDINA                        '           ...
#
#   SCHOOL_DST                                          WSHD_DIST GREEN_ACRE  \
# 0  b'281   '  b'Shingle Creek                               ...       b'N'
# 1  b'001   '  b'Shingle Creek                               ...       b'N'
# 2  b'      '  b'                                            ...       b'N'
# 3  b'281   '  b'Bassett Creek                               ...       b'N'
# 4  b'284   '  b'                                            ...       b'N'
#
#   OPEN_SPACE AG_PRESERV   AGPRE_ENRD   AGPRE_EXPD PARC_CODE  \
# 0       b'N'       b'N'  b'        '  b'        '  b'    0'
# 1       b'N'       b'N'  b'        '  b'        '  b'    0'
# 2       b'N'       b'N'  b'        '  b'        '  b'    0'
# 3       b'N'       b'N'  b'        '  b'        '  b'    0'
# 4       b'N'       b'N'  b'        '  b'        '  b'    0'
#
#                Shape_area               Shape_len
# 0  b' 7.25247600000e-002'  b' 9.55874206426e-001'
# 1  b' 7.25380050000e-002'  b' 9.55961240593e-001'
# 2  b' 7.25352550000e-002'  b' 9.55943566274e-001'
# 3  b' 7.25358400000e-002'  b' 9.55947921559e-001'
# 4  b' 7.25419200000e-002'  b' 9.55987121801e-001'
#
# [5 rows x 67 columns]

# %%
decode_string(df, cols)
df.head()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 429570 entries, 0 to 429569
# Data columns (total 67 columns):
# COUNTY_ID     429570 non-null object
# PIN           429570 non-null object
# BLDG_NUM      429570 non-null object
# PREFIX_DIR    429570 non-null object
# PREFIXTYPE    429570 non-null object
# STREETNAME    429570 non-null object
# STREETTYPE    429570 non-null object
# SUFFIX_DIR    429570 non-null object
# UNIT_INFO     429570 non-null object
# CITY          429570 non-null object
# CITY_USPS     429570 non-null object
# ZIP           429570 non-null object
# ZIP4          429570 non-null object
# PLAT_NAME     429570 non-null object
# BLOCK         429570 non-null object
# LOT           429570 non-null object
# ACRES_POLY    429570 non-null object
# ACRES_DEED    429570 non-null object
# USE1_DESC     429570 non-null object
# USE2_DESC     429570 non-null object
# USE3_DESC     429570 non-null object
# USE4_DESC     429570 non-null object
# MULTI_USES    429570 non-null object
# LANDMARK      429570 non-null object
# OWNER_NAME    429570 non-null object
# OWNER_MORE    429570 non-null object
# OWN_ADD_L1    429570 non-null object
# OWN_ADD_L2    429570 non-null object
# OWN_ADD_L3    429570 non-null object
# TAX_NAME      429570 non-null object
# TAX_ADD_L1    429570 non-null object
# TAX_ADD_L2    429570 non-null object
# TAX_ADD_L3    429570 non-null object
# HOMESTEAD     429570 non-null object
# EMV_LAND      429570 non-null object
# EMV_BLDG      429570 non-null object
# EMV_TOTAL     429570 non-null object
# TAX_CAPAC     429570 non-null object
# TOTAL_TAX     429570 non-null object
# SPEC_ASSES    429570 non-null object
# TAX_EXEMPT    429570 non-null object
# XUSE1_DESC    429570 non-null object
# XUSE2_DESC    429570 non-null object
# XUSE3_DESC    429570 non-null object
# XUSE4_DESC    429570 non-null object
# DWELL_TYPE    429570 non-null object
# HOME_STYLE    429570 non-null object
# FIN_SQ_FT     429570 non-null object
# GARAGE        429570 non-null object
# GARAGESQFT    429570 non-null object
# BASEMENT      429570 non-null object
# HEATING       429570 non-null object
# COOLING       429570 non-null object
# YEAR_BUILT    429570 non-null object
# NUM_UNITS     429570 non-null object
# SALE_DATE     429570 non-null object
# SALE_VALUE    429570 non-null object
# SCHOOL_DST    429570 non-null object
# WSHD_DIST     429570 non-null object
# GREEN_ACRE    429570 non-null object
# OPEN_SPACE    429570 non-null object
# AG_PRESERV    429570 non-null object
# AGPRE_ENRD    429570 non-null object
# AGPRE_EXPD    429570 non-null object
# PARC_CODE     429570 non-null object
# Shape_area    429570 non-null object
# Shape_len     429570 non-null object
# dtypes: object(67)
# memory usage: 219.6+ MB

# %%
type(df['STREETNAME'].ix[1])
# Out:
# bytes

# %%
clean_b = lambda x: re.sub(r'(b\')(\w*)(\')',r'\2', x)
census['name'] = census['name'].apply(clean_dashes)

# %%
import re
x = "b'LYNDALE AVE N '"
y = re.sub(r'(b\')(\w*)(\')',r'\2', x)
y
# Out:
# "b'LYNDALE AVE N '"
