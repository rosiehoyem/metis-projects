# %% [markdown]
# # Property Scrape

# %%
import pandas as pd
import numpy as np

import requests
from bs4 import BeautifulSoup

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

import os
chromedriver = "./chromedriver"
os.environ["webdriver.chrome.driver"] = chromedriver

driver = webdriver.Chrome(chromedriver)

# %%
public_df = pd.read_csv('../data/raw/wcmsp-185933.csv')
public_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 16 columns):
# Organization Name                           158 non-null object
# Property Name                               158 non-null object
# Address                                     158 non-null object
# Postal Code                                 158 non-null int64
# ENERGY STAR Score                           158 non-null int64
# Primary Property Type                       158 non-null object
# Floor Area (Buildings) (ft²)                158 non-null int64
# Floor Area (Parking) (ft²)                  158 non-null int64
# Year Built                                  158 non-null int64
# Total GHG Emissions (Metric Tons CO2e)      158 non-null int64
# Site EUI (kBtu/ft²)                         158 non-null int64
# Weather Normalized Site EUI (kBtu/ft²)      158 non-null int64
# Source EUI (kBtu/ft²)                       158 non-null int64
# Weather Normalized Source EUI (kBtu/ft²)    158 non-null int64
# Water Use (kgal)                            158 non-null int64
# Unnamed: 15                                 0 non-null float64
# dtypes: float64(1), int64(11), object(4)
# memory usage: 19.8+ KB

# %%
private_df = pd.read_csv('../data/raw/wcmsp-185935.csv')

# %%
private_df.head()
# Out:
#               Address Postal Code  ENERGY STAR Score Primary Property Type  \
# 0   201 Chicago Ave S       55415                 36                Office
# 1  1011 Nicollet Mall       55403                 68                Office
# 2    4701 Beard Ave S       55410                  0                 Other
# 3         8 60Th St W       55419                 76      Worship Facility
# 4      700 10Th Ave S       55415                 89                Office
#
#    Floor Area (Building) (ft²)  Floor Area (Parking) (ft²)  Year Built  \
# 0                        62400                           0        2012
# 1                        59479                           0        1920
# 2                        59172                           0        1914
# 3                        60640                       62000        1959
# 4                        60528                           0        1920
#
#    Total GHG Emissions (Metric Tons CO2e)  Site EUI (kBtu/ft²)  \
# 0                                     971                  115
# 1                                     986                   90
# 2                                    1622                  157
# 3                                     268                   50
# 4                                     504                   74
#
#    Weather Normalized Site EUI (kBtu/ft²)  Source EUI (kBtu/ft²)  \
# 0                                     118                    251
# 1                                      93                    256
# 2                                     160                    427
# 3                                      54                     77
# 4                                      77                    136
#
#    Weather Normalized Source EUI (kBtu/ft²)  Water Use (kgal)  Unnamed: 13  \
# 0                                       252               708          NaN
# 1                                       266               882          NaN
# 2                                       428               163          NaN
# 3                                        81               674          NaN
# 4                                       140               414          NaN
#
#        search_address
# 0   201 Chicago ave S
# 1  1011 Nicollet Mall
# 2    4701 Beard ave S
# 3         8 60Th St W
# 4      700 10Th ave S

# %%
# Clean the address strings to the required format for Hennepin County Property Info search

def clean_addresses(df):
    df['search_address'].replace('Avenue', 'ave', inplace=True, regex=True)
    df['search_address'].replace('Ave\.', 'ave', inplace=True, regex=True)
    df['search_address'].replace('Ave', 'ave', inplace=True, regex=True)
    df['search_address'].replace('NE', 'n e', inplace=True, regex=True)
    df['search_address'].replace('SE', 's e', inplace=True, regex=True)
    df['search_address'].replace('Southeast', 's e', inplace=True, regex=True)
    df['search_address'].replace('Northeast', 'n e', inplace=True, regex=True)
    df['search_address'].replace('Southwest', 's w', inplace=True, regex=True)
    df['search_address'].replace('Curve', 'cur', inplace=True, regex=True)
    df['search_address'].replace('Parkway', 'pkwy', inplace=True, regex=True)
    df['search_address'].replace('Terrace', 'ter', inplace=True, regex=True)
    df['search_address'].replace('East', 'e', inplace=True, regex=True)
    df['search_address'].replace('S\.', 's', inplace=True, regex=True)
    df['search_address'].replace('South', 's', inplace=True, regex=True)
    df['search_address'].replace('Boulevard', 'blvd', inplace=True, regex=True)
    df['search_address'].replace('Curve', 'cur', inplace=True, regex=True)
    df['search_address'].replace('Drive', 'dr', inplace=True, regex=True)
    df['search_address'].replace('Trail', 'tr', inplace=True, regex=True)
    df['search_address'].replace('North', 'n', inplace=True, regex=True)
    df['search_address'].replace('Circle', 'cir', inplace=True, regex=True)
    df['search_address'].replace('Highway', 'hwy', inplace=True, regex=True)
    df['search_address'].replace('Road', 'rd', inplace=True, regex=True)
    df['search_address'].replace('Court', 'ct', inplace=True, regex=True)
    df['search_address'].replace('Lane', 'ln', inplace=True, regex=True)
    df['search_address'].replace('St\.', 'st', inplace=True, regex=True)
    df['search_address'].replace('Street', 'st', inplace=True, regex=True)
    df['search_address'].replace('street', 'st', inplace=True, regex=True)
    df['search_address'].replace('steet', 'st', inplace=True, regex=True)
    df['search_address'].replace('Northwest', 'n w', inplace=True, regex=True)
    df['search_address'].replace('West', 'w', inplace=True, regex=True)
    df['search_address'].replace('County', 'co', inplace=True, regex=True)
    df['search_address'].replace('Number', 'no', inplace=True, regex=True)
    df['search_address'].replace('Sixth', '6th', inplace=True, regex=True)

# %%
private_df['search_address'] = private_df['Address']
clean_addresses(private_df)
private_df.search_address
# Out:
# 0                           201 Chicago ave S
# 1                          1011 Nicollet Mall
# 2                            4701 Beard ave S
# 3                                 8 60Th St W
# 4                              700 10Th ave S
# 5                               805 2Nd ave S
# 6                                123 3Rd St N
# 7                          700 Humboldt ave N
# 8                                700 3Rd St S
# 9                               525 w 54th St
# 10                              920 Lake St E
# 11                              560 6Th ave N
# 12                          3800 Pleasant ave
# 13                               84 10th St S
# 14                             1455 Lake St W
# 15                               233 Park ave
# 16                            2850 26Th ave S
# 17                        300 Industrial Blvd
# 18                              910 26Th St E
# 19                           2800 Chicago ave
# 20                          2410 Irving ave N
# 21                          4021 Thomas ave N
# 22                            1500 6Th St n e
# 23                             1630 4Th St Ne
# 24                           2828 Chicago ave
# 25                          5000 Oliver ave N
# 26                       300 Washington ave s
# 27                          5937 Nicollet ave
# 28                         2123 Clinton ave S
# 29                       2323 Riverside ave S
#                         ...
# 227                             913 26Th St E
# 228                       1107 Harmon Pl Mpls
# 229                        3660 Technology Dr
# 230                    1540 New Brighton Blvd
# 231                      501 Nicollet Mall #D
# 232                            4225 3rd ave S
# 233    606 24th ave S -Fairview St Marys Bldg
# 234                              119 4th St N
# 235                            2500 Lake St E
# 236        1520 New Brighton Blvd -home Depot
# 237                            16 9th St S #1
# 238                              900 4th St N
# 239                            610 22nd ave S
# 240                           1615 River Rd W
# 241                          2530 Chicago ave
# 242                            2101 Summer St
# 243                             400 2nd ave S
# 244                              401 3rd St N
# 245                         1750 Hennepin ave
# 246                    1650 New Brighton Blvd
# 247                            3200 Lake St W
# 248                          528 Hennepin ave
# 249             706 2nd ave S -baker Building
# 250                       2021 Hennepin ave E
# 251                             310 4th ave S
# 252                       1012 Lasalle ave #B
# 253                            2500 3rd ave S
# 254                            910 Elliot ave
# 255                            2840 4th ave S
# 256                      3433 Broadway St n e
# Name: search_address, dtype: object

# %%
public_df['search_address'] = public_df['Address']
clean_addresses(public_df)
public_df.search_address
# Out:
# 0               1800 Chicago s
# 1             300 Nicolet Mall
# 2            330 south 12th st
# 3                 110 s 4th st
# 4            530 Chicago ave s
# 5                    300 s 6th
# 6           525 Portland ave s
# 7                 701 Park ave
# 8                    626 s 6th
# 9              1313 Penn ave N
# 10            1315 Lowry ave n
# 11                 401 4 ave s
# 12         2810 Nicollet ave s
# 13            935 Hennepin ave
# 14             915 LaSalle ave
# 15                350 s 5th st
# 16               309 2nd ave s
# 17           1200 Currie ave n
# 18             25 37th ave n e
# 19               333 3rd ave s
# 20               121 E 15TH ST
# 21            415 south 3rd st
# 22                424 4th st s
# 23           4131 Dupont ave n
# 24                25 s 11th st
# 25          6036 Harriet ave s
# 26                 31 n 9th st
# 27              1901 e 26th st
# 28              1030 2nd ave s
# 29              1001 2nd ave s
#                 ...
# 128             3017 E 31st st
# 129            2600 44th ave N
# 130            3333 Penn ave N
# 131           3333 Grand ave S
# 132            415 4th ave s e
# 133             807 27th ave N
# 134           1500 James ave N
# 135          2955 Hayes st n e
# 136            4315 31st ave S
# 137           812 Plymouth ave
# 138            1607 51st ave N
# 139           910 Hennepin ave
# 140           710 Hennepin ave
# 141       2250 Garfield st n e
# 142           66 Malcom st s e
# 143              201 w 49th st
# 144            4029 28th ave S
# 145            3524 42nd ave S
# 146            2309 28th ave S
# 147    1201 University ave n e
# 148            3131 19th ave S
# 149             3414 w 47th st
# 150           805 Hennepin ave
# 151             3100 E 28th st
# 152          1510 Glenwood ave
# 153            1800 34th ave S
# 154            5625 23rd ave S
# 155              315 w 26th st
# 156           3345 Chicago ave
# 157       5821 Wentworth ave S
# Name: search_address, dtype: object

# %%
import re
import string

def selenium_search_url(driver, search_url, address):
    driver.get(search_url)

    address_num = address.split(" ")[0]
    address_street = address.split(" ")[1:]
    address_box = driver.find_element_by_id("INPUT1")
    address_box.send_keys(address_num)
    street_box = driver.find_element_by_id("INPUT3")
    street_box.send_keys(address_street)

    submit_button = driver.find_element_by_id("INPUT4")
    submit_button.click()
    
    property_url = driver.current_url
    print(property_url)

    content = (driver.page_source).encode('ascii', 'ignore')
    return content

def create_soup(content):
    soup = BeautifulSoup(content,"lxml")
    return soup

def search_multiple_properties(address, trs, data):
    for tr in trs:
        match = re.search(r'(pid\=)(\d*)(\"\>)', str(tr))
        if match:
            print(match.group(2))
            url = "http://www16.co.hennepin.mn.us/pins/pidresult.jsp?pid=" + match.group(2)
            driver.get(url)
            content = driver.page_source
            soup = create_soup(content)
            parse_property_page(address, soup, data) 
    return data

def parse_property_page(address, soup, data):
    new_record = {}
    
    if "Direct Debit program" in soup.find(id='TABLE_DETAILS').find_all('tr')[6].find_all('td')[0].text.strip():
        property_id = int(soup.find(id='TABLE_DETAILS').find_all('tr')[7].find_all('td')[1].text.strip().replace('-',''))
        new_record['address'] = address 
        new_record['property_id'] = property_id 
        new_record['construction_year'] = soup.find(id='TABLE_DETAILS').find_all('tr')[10].find_all('td')[4].text.strip() 
        new_record['owner_name'] = soup.find(id='TABLE_DETAILS').find_all('tr')[15].find_all('td')[1].text.strip()

        if "NO SALE INFORMATION ON FILE" in soup.find(id='TABLE_DETAILS').find_all('tr')[24].find_all('td')[0].text.strip():
            new_record['est_market_value'] = soup.find(id='TABLE_DETAILS').find_all('tr')[39].find_all('td')[1].text.strip()
            new_record['tax_market_value'] = soup.find(id='TABLE_DETAILS').find_all('tr')[40].find_all('td')[1].text.strip() 
            new_record['total_net_tax'] = soup.find(id='TABLE_DETAILS').find_all('tr')[42].find_all('td')[1].text.strip() 
            new_record['total_tax'] = soup.find(id='TABLE_DETAILS').find_all('tr')[45].find_all('td')[1].text.strip()
        else:
            new_record['sale_date'] = soup.find(id='TABLE_DETAILS').find_all('tr')[24].find_all('td')[1].text.strip()
            new_record['sale_price'] = soup.find(id='TABLE_DETAILS').find_all('tr')[25].find_all('td')[1].text.strip()
            new_record['transaction_type'] = soup.find(id='TABLE_DETAILS').find_all('tr')[26].find_all('td')[1].text.strip()
            #positions with NO sales section
            new_record['est_market_value'] = soup.find(id='TABLE_DETAILS').find_all('tr')[41].find_all('td')[1].text.strip()
            new_record['tax_market_value'] = soup.find(id='TABLE_DETAILS').find_all('tr')[42].find_all('td')[1].text.strip() 
            new_record['total_net_tax'] = soup.find(id='TABLE_DETAILS').find_all('tr')[44].find_all('td')[1].text.strip() 
            new_record['total_tax'] = soup.find(id='TABLE_DETAILS').find_all('tr')[47].find_all('td')[1].text.strip()
    
    elif "State Copy to be used when filing for the" in soup.find(id='TABLE_DETAILS').find_all('tr')[4].find_all('td')[0].text.strip():
        property_id = int(soup.find(id='TABLE_DETAILS').find_all('tr')[8].find_all('td')[1].text.strip().replace('-',''))
        new_record['address'] = address 
        new_record['property_id'] = property_id 
        new_record['construction_year'] = soup.find(id='TABLE_DETAILS').find_all('tr')[11].find_all('td')[4].text.strip() 
        new_record['owner_name'] = soup.find(id='TABLE_DETAILS').find_all('tr')[16].find_all('td')[1].text.strip()
        
        if "NO SALE INFORMATION ON FILE" in soup.find(id='TABLE_DETAILS').find_all('tr')[25].find_all('td')[0].text.strip():
            new_record['est_market_value'] = soup.find(id='TABLE_DETAILS').find_all('tr')[40].find_all('td')[1].text.strip()
            new_record['tax_market_value'] = soup.find(id='TABLE_DETAILS').find_all('tr')[41].find_all('td')[1].text.strip() 
            new_record['total_net_tax'] = soup.find(id='TABLE_DETAILS').find_all('tr')[43].find_all('td')[1].text.strip() 
            new_record['total_tax'] = soup.find(id='TABLE_DETAILS').find_all('tr')[46].find_all('td')[1].text.strip()
        else:
            new_record['sale_date'] = soup.find(id='TABLE_DETAILS').find_all('tr')[25].find_all('td')[1].text.strip()
            new_record['sale_price'] = soup.find(id='TABLE_DETAILS').find_all('tr')[26].find_all('td')[1].text.strip()
            new_record['transaction_type'] = soup.find(id='TABLE_DETAILS').find_all('tr')[27].find_all('td')[1].text.strip()
            #positions with sales section
            new_record['est_market_value'] = soup.find(id='TABLE_DETAILS').find_all('tr')[42].find_all('td')[1].text.strip()
            new_record['tax_market_value'] = soup.find(id='TABLE_DETAILS').find_all('tr')[43].find_all('td')[1].text.strip() 
            new_record['total_net_tax'] = soup.find(id='TABLE_DETAILS').find_all('tr')[45].find_all('td')[1].text.strip() 
            new_record['total_tax'] = soup.find(id='TABLE_DETAILS').find_all('tr')[48].find_all('td')[1].text.strip()
    else:  
        property_id = int(soup.find(id='TABLE_DETAILS').find_all('tr')[6].find_all('td')[1].text.strip().replace('-',''))
        new_record['address'] = address 
        new_record['property_id'] = property_id 
        new_record['construction_year'] = soup.find(id='TABLE_DETAILS').find_all('tr')[9].find_all('td')[4].text.strip() 
        new_record['owner_name'] = soup.find(id='TABLE_DETAILS').find_all('tr')[14].find_all('td')[1].text.strip()
        
        if "NO SALE INFORMATION ON FILE" in soup.find(id='TABLE_DETAILS').find_all('tr')[23].find_all('td')[0].text.strip():
            new_record['est_market_value'] = soup.find(id='TABLE_DETAILS').find_all('tr')[38].find_all('td')[1].text.strip()
            new_record['tax_market_value'] = soup.find(id='TABLE_DETAILS').find_all('tr')[39].find_all('td')[1].text.strip() 
            new_record['total_net_tax'] = soup.find(id='TABLE_DETAILS').find_all('tr')[41].find_all('td')[1].text.strip() 
            new_record['total_tax'] = soup.find(id='TABLE_DETAILS').find_all('tr')[44].find_all('td')[1].text.strip()
        else:
            new_record['sale_date'] = soup.find(id='TABLE_DETAILS').find_all('tr')[23].find_all('td')[1].text.strip()
            new_record['sale_price'] = soup.find(id='TABLE_DETAILS').find_all('tr')[24].find_all('td')[1].text.strip()
            new_record['transaction_type'] = soup.find(id='TABLE_DETAILS').find_all('tr')[25].find_all('td')[1].text.strip()
            #positions with NO sales section
            new_record['est_market_value'] = soup.find(id='TABLE_DETAILS').find_all('tr')[40].find_all('td')[1].text.strip()
            new_record['tax_market_value'] = soup.find(id='TABLE_DETAILS').find_all('tr')[41].find_all('td')[1].text.strip() 
            new_record['total_net_tax'] = soup.find(id='TABLE_DETAILS').find_all('tr')[43].find_all('td')[1].text.strip() 
            new_record['total_tax'] = soup.find(id='TABLE_DETAILS').find_all('tr')[46].find_all('td')[1].text.strip()          
    
    new_record['land_market_value'] = soup.find(id='Table_Detail').find_all('tr')[3].find_all('td')[1].text.strip() 
    new_record['building_market_value'] = soup.find(id='Table_Detail').find_all('tr')[4].find_all('td')[1].text.strip() 
    new_record['total_market_value'] = soup.find(id='Table_Detail').find_all('tr')[6].find_all('td')[1].text.strip()
    new_record['homestead_mrkt_val_excl'] = soup.find(id='Table_Detail').find_all('tr')[9].find_all('td')[1].text.strip()
    new_record['property_type'] = soup.find(id='Table_Detail').find_all('tr')[11].find_all('td')[1].text.strip()
    new_record['homestead_status'] = soup.find(id='Table_Detail').find_all('tr')[12].find_all('td')[1].text.strip()

    data[property_id] = new_record
    return data

# %%
def run_scraper(df):
    chromedriver = "./chromedriver"
    driver = webdriver.Chrome(chromedriver)
    search_url="http://www16.co.hennepin.mn.us/pins/addrsrch.jsp"

    data = {}
    for index, row in df.iterrows():
        try:
            content = selenium_search_url(driver, search_url, row['search_address'])
            soup = create_soup(content)

            if soup.find(id='TABLE_DETAILS') and soup.find(id='TABLE_DETAILS').find_all('tr')[6].find_all('td')[1].text:
                print("Found " + row['Address'] + ": " + soup.find(id='TABLE_DETAILS').find_all('tr')[6].find_all('td')[1].text)
                parse_property_page(row['Address'], soup, data)
            elif soup.find(class_="notfound", string="No records found"):
                print("No records found for " +  row['Address'])
            elif soup.find("span", string="Click on property ID for details"):
                print(row['Address'] + " has multiple properties")
                select = driver.find_element_by_name("ps")
                select.send_keys('100')
                submit_button = driver.find_element_by_id("INPUT4")
                submit_button.click()

                content = (driver.page_source).encode('ascii', 'ignore')
                soup = create_soup(content)
                trs = soup.find(id='TABLE1').find_all('tr')
                search_multiple_properties(row['Address'], trs, data)
            else:
                print("Something went wrong " + row['Address'])
        except Exception:
            print("Exception on " +  row['Address'])
            pass
    return data

# %%
public_property_info = run_scraper(public_df)
# Out:
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 1800 Chicago S.: 26-029-24-33-0002
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 300 Nicolet Mall: 22-029-24-44-0012
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 330 south 12th st
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 110 S. 4th St.
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 530 Chicago Avenue South: 26-029-24-21-0070
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 300 S. Sixth
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 525 Portland Ave South
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 701 Park Avenue has multiple properties
# 2602924240052
# Exception on 701 Park Avenue
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 626 S. Sixth
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 1313 Penn Ave N: 17-029-24-44-0212
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 1315 Lowry Avenue North has multiple properties
# 0902924420043
# Exception on 1315 Lowry Avenue North
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 401 4 Ave South
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Exception on 2810 Nicollet Ave. South
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 935 Hennepin Avenue
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 915 LaSalle Avenue
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 350 South 5th Street
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 309 2nd Avenue South: 23-029-24-33-0009
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 1200 Currie Ave North
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 25 37th Avenue NE
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 333 3rd Avenue South has multiple properties
# 2202924130147
# Exception on 333 3rd Avenue South
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 121 E 15TH ST
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 415 south 3rd Street
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 424 4th Street South has multiple properties
# 1811921210063
# Exception on 424 4th Street South
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 4131 Dupont Avenue North: 04-029-24-13-0172
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 25 South 11th Street
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 6036 Harriet Avenue South
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 31 North 9th Street
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 1901 East 26th Street
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 1030 2nd Avenue South
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 1001 2nd Avenue South has multiple properties
# 2102924430119
# Exception on 1001 2nd Avenue South
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 711 South 2nd Street
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 1301 second Avenue South
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 1111 Marquette Avenue South: 27-029-24-13-0039
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 1111 Marquette Avenue South: 27-029-24-13-0039
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 117 South 12th Street
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 3000 Minnehaha Avenue has multiple properties
# 0102824120129
# Exception on 3000 Minnehaha Avenue
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 1925 Plymouth Avenue North: 21-029-24-22-0205
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 250 South 4th Street
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 212 9th Avenue South: 23-029-24-43-0195
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 661 5th Avenue North: 22-029-24-31-0036
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 318 2nd Avenue North has multiple properties
# 2202924420099
# Exception on 318 2nd Avenue North
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 516 2nd Avenue North has multiple properties
# 2202924420090
# Exception on 516 2nd Avenue North
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 101 North 9th Street
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 300 Border Avenue: 22-029-24-32-0015
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 727 Vineland
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 4500 Marshall Street NE has multiple properties
# 1011921230014
# Exception on 4500 Marshall Street NE
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 2500 57th St W
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 1320 29th Ave NE: 12-029-24-21-0168
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 2000 2nd St NE has multiple properties
# 2102924330077
# Exception on 2000 2nd St NE
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 2728 39th Ave S
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 3101 Bryant Ave S
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 3332 20th Ave S: 01-028-24-23-0182
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 5001 Irving Ave N: 11-118-21-14-0090
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 2307 17th Ave S
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 1000 14th St E
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 621 29th Ave N: 10-029-24-33-0001
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 1615 Dowling Ave N
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 4800 Grand Ave S
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 4305 42nd St E has multiple properties
# 0702823410167
# Exception on 4305 42nd St E
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 3030 53rd St E: 13-028-24-44-0001
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 1328 58th St W
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 2101 Franklin Ave W has multiple properties
# 3002923440036
# Exception on 2101 Franklin Ave W
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 2701 44th St E: Print
#
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 2401 E Minnehaha Pkwy
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 3100 43rd St W: Print
#
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 690 13th Ave NE
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 3435 36th Ave S: 06-028-23-31-0178
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 1382 Willow St: 27-029-24-24-0005
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 112 Williams Ave SE
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 3900 Bryant Ave S has multiple properties
# 0402924410102
# Exception on 3900 Bryant Ave S
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 1345 West Minnehaha Pkwy
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 2318 29th Ave S: 36-029-24-14-0171
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 906 47th St E: 14-028-24-21-0004
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 5531 39th Ave S
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 2117 W River Rd
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 1801 James Ave N has multiple properties
# 1602924310001
# Exception on 1801 James Ave N
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 1306 Central Ave N: 14-029-24-14-0045
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 1616 Buchanon St NE
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 620 34th St W has multiple properties
# 1002924220110
# Exception on 620 34th St W
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 610 Kenwood Parkway
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 600 Kenwood Pkwy has multiple properties
# 2412022140062
# Exception on 600 Kenwood Pkwy
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 414 Diamond Lake Rd E has multiple properties
# 1502824440001
# Exception on 414 Diamond Lake Rd E
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 730 22nd St E
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 3523 48th St W: 17-028-24-24-0205
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 2323 11th Ave S
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 3400 15th Ave S
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 4055 Nicollet Ave S
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 1900 40th St E: 12-028-24-22-0176
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 3800 Bryant Ave S: 04-029-24-41-0132
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 2700 12th Ave S
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 901 15th Ave SE has multiple properties
# 2602924430114
# Exception on 901 15th Ave SE
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 1810 34th Ave NE: Print
#
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 4400 Dupont Ave N: Print
#
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 2600 Grand Ave S has multiple properties
# 3402924320208
# Exception on 2600 Grand Ave S
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 2251 Hayes St NE
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 701 4th Ave S has multiple properties
# 2602924220065
# Exception on 701 4th Ave S
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 2727 10th Ave S: 35-029-24-31-0101
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 5757 Irving Ave S: 21-028-24-24-0140
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 256 Upton Ave S
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 2501 West 56th Street
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 1315 East 38th Street
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 4237 Colfax Ave S has multiple properties
# 0402924110003
# Exception on 4237 Colfax Ave S
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 919 Emerson Ave
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 252 Upton Avenue South: 29-029-24-12-0012
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 1601 West 50th Street
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 3350 4th Street North: 10-029-24-23-0189
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 1250 West Braodway
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 3900 West River Parkway
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 700 22nd Ave NE: 11-029-24-44-0094
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 1421 Spruce Place: 27-029-24-31-0059
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 4645 4th Ave South: 15-028-24-11-0056
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 3611 20th Ave S.: 01-028-24-33-0001
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 3416 4th Ave S has multiple properties
# 0302824410056
# Exception on 3416 4th Ave S
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 1220 East 54th Street
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 1601 Aldrich Ave N
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 501 Irving Ave N
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 4320 Newton Ave N: 04-029-24-22-0110
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 4201 42nd Ave S: Print
#
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 3733 43rd Ave S.: 06-028-23-44-0107
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 1200 West 26th Street
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 5025 Bryant Avenue North has multiple properties
# 1211821240101
# Exception on 5025 Bryant Avenue North
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 1501 30th Ave N
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 5209 30th Ave S: 13-028-24-44-0002
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 5720 Emerson Ave S: 21-028-24-13-0028
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 2013 Penn Ave S
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 4030 Chowen Ave S: 08-028-24-23-0084
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 4912 Vincent Ave S: 17-028-24-13-0177
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 2131 12th Ave N: 21-029-24-22-0064
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 3017 E 31st Street
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 2600 44th Ave N
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 3333 Penn Ave N
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 3333 Grand Ave S
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 415 4th Ave SE has multiple properties
# 1402924340013
# Exception on 415 4th Ave SE
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 807 27th Ave N has multiple properties
# 0902924440247
# Exception on 807 27th Ave N
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 1500 James Ave N: 16-029-24-34-0046
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 2955 Hayes Street NE: 01-029-24-43-0182
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 4315 31st Ave S: 07-028-23-32-0100
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 812 Plymouth Ave.: 16-029-24-44-0146
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 1607 51st Ave N
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 910 Hennepin Ave: 27-029-24-21-0030
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 710 Hennepin Ave: 22-029-24-43-0209
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 2250 Garfield Street NE: 12-029-24-42-0142
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 66 Malcom Street SE: 30-029-23-42-0021
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 201 West 49th Street
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 4029 28th Ave S: 12-028-24-14-0163
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 3524 42nd Ave S: 06-028-23-42-0186
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 2309 28th Ave S
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 1201 University Ave NE: Print
#
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 3131 19th Ave S: 01-028-24-22-0076
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 3414 West 47th street
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 805 Hennepin Ave
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 3100 E 28th Street
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 1510 Glenwood Ave
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 1800 34th Ave S: 01-029-24-13-0103
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 5625 23rd Ave S: 24-028-24-24-0001
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 315 West 26th Street
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 3345 Chicago Ave: 02-028-24-24-0082
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 5821 Wentworth Ave S: 22-028-24-31-0010

# %%
import pickle

with open('0201_public_prop_dict.pkl', 'wb') as picklefile:
    pickle.dump(public_property_info, picklefile)

# %%
private_property_info = run_scraper(private_df)
# Out:
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 201 Chicago Ave S: 23-029-24-43-0394
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 1011 Nicollet Mall
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 4701 Beard Ave S: 17-028-24-21-0100
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 8 60Th St W: 22-028-24-34-0118
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 700 10Th Ave S has multiple properties
# 2602924240086
# 2602924240086
# 2402924240052
# 2402924240176
# 2402924240185
# 2402924240186
# 2402924240187
# 2402924240188
# 2402924240189
# 2402924240190
# 2402924240191
# 2402924240192
# 2402924240193
# 2402924240194
# 2402924240177
# 2402924240195
# 2402924240196
# 2402924240197
# 2402924240198
# 2402924240199
# 2402924240178
# 2402924240179
# 2402924240180
# 2402924240181
# 2402924240182
# 2402924240183
# 2402924240184
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 805 2Nd Ave S has multiple properties
# 2702924110085
# 2702924110085
# 2411722130087
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 123 3Rd St N: 22-029-24-41-0085
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 700 Humboldt Ave N: 21-029-24-13-0004
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 700 3Rd St S has multiple properties
# 3511723230047
# 3511723230047
# 2302924110285
# 2602924210139
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 525 West 54th St
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 920 Lake St E
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 560 6Th Ave N: 22-029-24-23-0140
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 3800 Pleasant Ave: 10-028-24-22-0092
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 84 10th St S: 27-029-24-12-0096
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 1455 Lake St W: 04-028-24-21-0016
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 233 Park Ave: 23-029-24-34-0721
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 2850 26Th Ave S: 36-029-24-43-0088
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 300 Industrial Blvd: 18-029-23-44-0018
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 910 26Th St E has multiple properties
# 1102924140067
# 1102924140067
# 1902923130012
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 2800 Chicago Ave: 35-029-24-33-0243
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 2410 Irving Ave N has multiple properties
# 1602924210184
# 1602924210184
# 3302924240048
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 4021 Thomas Ave N: 05-029-24-13-0012
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 1500 6Th St NE: 14-029-24-21-0090
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 1630 4Th St Ne
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 2828 Chicago Ave has multiple properties
# 3502924330241
# 3502924330241
# 3502924330244
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 5000 Oliver Ave N has multiple properties
# 1111821130004
# 1111821130004
# 1602824320001
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 300 Washington Ave s has multiple properties
# 2202924140023
# 2202924140023
# 2302924340079
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 5937 Nicollet Ave: 22-028-24-42-0075
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 2123 Clinton Ave S: 34-029-24-11-0123
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 2323 Riverside Ave S has multiple properties
# 1502924120035
# 1502924120035
# 2502924340091
# 2502924340095
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 1601 Hennepin Ave: 27-029-24-23-0028
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 323 Stinson Blvd: 18-029-23-33-0010
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 112 19th Ave NE: 25-029-24-22-0063
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 921 Washington Ave S: 26-029-24-12-0090
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 3100 Lake St W has multiple properties
# 1711722120037
# 1711722120037
# 3202924430382
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 2407 University Ave SE has multiple properties
# 1802924220229
# 1802924220229
# 1102924320052
# 3002923210042
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 2730 31St St E: 01-028-24-11-0123
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 1450 Lake St W: 33-029-24-34-0112
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 1917 Logan Ave S: 28-029-24-34-0151
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 17 Washington Ave N has multiple properties
# 2902924120131
# 2902924120131
# 2202924410130
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 2400 Park Ave has multiple properties
# 3502924230166
# 3502924230166
# 3502924230173
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 2329 Central Ave NE: 12-029-24-32-0235
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 4652 Lyndale Ave N has multiple properties
# 1211821430074
# 1211821430074
# 1602824110013
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 1700 2Nd St Ne has multiple properties
# 2102924340127
# 2102924340127
# 1402924220197
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 333 S 12th St
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 1201 Broadway W: 24-029-24-13-0135
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 201 2Nd Ave SE has multiple properties
# 2302924130628
# 2302924130628
# 3411723110139
# 2302924210335
# 1811921230144
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 2808 Hennepin Ave
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 501 2Nd St S has multiple properties
# 1811921220096
# 1811921220096
# 1311922110041
# 2302924110260
# 2202924130221
# 1402924340108
# 2302924340677
# 1811921310022
# 1811921310023
# 1811921310090
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Exception on 1900 Nicollet Ave
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 25 Grove St: Print
#
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 507 23rd Ave S: 25-029-24-31-0021
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 10 5th St S has multiple properties
# 2411722420016
# 2411722420016
# 2202924430007
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 2300 Chicago Ave: 35-029-24-22-0102
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 818 2nd St S -guthrie Theatre has multiple properties
# 2302924430202
# 2302924430202
# 2302924430203
# 2302924430204
# 2302924430205
# 2302924430206
# 2302924430207
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 601 Stinson Blvd: 18-029-23-32-0034
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 330 2nd Ave: 23-029-24-33-0012
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 400 1st Ave N has multiple properties
# 2202924420059
# 2202924420059
# 1811921220012
# 2202924140554
# 2202924140555
# 2202924140556
# 2202924140557
# 2202924140558
# 2202924140559
# 2202924140560
# 2202924140561
# 2202924140562
# 2202924140563
# 2202924140564
# 2202924140565
# 2202924140566
# 2202924140567
# 2202924140568
# 2202924140569
# 2202924140570
# 2202924140571
# 2202924140572
# 2202924140573
# 2202924140574
# 2202924140575
# 2202924140576
# 2202924140577
# 2202924140578
# 2202924140579
# 2202924140580
# 2202924140581
# 2202924140582
# 2202924140583
# 2202924140584
# 2202924140585
# 2202924140586
# 2202924140587
# 2202924140588
# 2202924140589
# 2202924140590
# 2202924140591
# 2202924140592
# 2202924140593
# 2202924140594
# 2202924140595
# 2202924140596
# 2202924140597
# 2202924140598
# 2202924140599
# 2202924140600
# 2202924140601
# 2202924140602
# 2202924140603
# 2202924140604
# 2202924140605
# 2202924140606
# 2202924140607
# 2202924140608
# 2202924140609
# 2202924140610
# 2202924140611
# 2202924140612
# 2202924140613
# 2202924140614
# 2202924140615
# 2202924140616
# 2202924140617
# 2202924140618
# 2202924140619
# 2202924140620
# 2202924140621
# 2202924140622
# 2202924140623
# 2202924140624
# 2202924140625
# 2202924140626
# 2202924140627
# 2202924140628
# 2202924140629
# 2202924140630
# 2202924140631
# 2202924140632
# 2202924140633
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 400 4th St S has multiple properties
# 1811921210060
# 1811921210060
# 1402924340040
# 2302924330037
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 200 3rd Ave N -colonial Warehouse has multiple properties
# 2202924140156
# 2202924140156
# 3411723120074
# 2202924410101
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 3027 Hennepin Ave
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 517 Marquette Ave: 22-029-24-44-0109
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 900 2nd Ave S -international Center has multiple properties
# 2702924110160
# 2702924110160
# 1402924320057
# 2302924430208
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 1330 Nicollet Mall
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 801 Lasalle Ave: 27-029-24-12-0148
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 818 Dunwoody Blvd: 28-029-24-14-0012
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 821 Marquette Ave: 14-029-24-32-0088
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 200 5th St S has multiple properties
# 1811921310072
# 1811921310072
# 2302924330878
# 2302924140025
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 1313 Nicollet Mall: 27-029-24-13-0073
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 570 6th Ave N
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 45 5th St S
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 911 Marquette Ave
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 507 23Rd Ave S: 25-029-24-31-0021
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 825 Nicollet Mall - Medical Arts Bldg: 27-029-24-12-0090
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 524 23Rd Ave S: 25-029-24-31-0096
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 416 1st Ave N has multiple properties
# 2202924420021
# 2202924420021
# 1811921220014
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 3106 Nicollet Ave: 03-028-24-21-0283
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 88 6th St S: 22-029-24-44-0057
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 1200 Marquette Ave: 27-029-24-13-0266
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 1500 Washington Ave S has multiple properties
# 1702924430052
# 1702924430052
# 1702924430053
# 1502924340111
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 20 Washington Ave S has multiple properties
# 2711723240095
# 2711723240095
# 2902924120104
# 2302924320006
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 615 2nd Ave S: 27-029-24-11-0032
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 1300 Godward St: 18-029-23-13-0023
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 717 25th Ave S has multiple properties
# 1602924110229
# 1602924110229
# 2502924430171
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 2101 Kennedy St NE has multiple properties
# 1302924410020
# 1302924410020
# 1302924410026
# 3202924110128
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 651 Nicollet Mall has multiple properties
# 2202924440123
# 2202924440123
# 2202924440124
# 2202924440125
# 2202924440126
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 1101 Lasalle Ave has multiple properties
# 2702924130293
# 2702924130293
# 0511722320050
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 30 5th St S: 24-117-22-42-0013
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 700 Nicollet Mall: 27-029-24-12-0032
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 2801 4th Ave S -south Building #5: 34-029-24-44-0154
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 109 7th St S - Roanoke Bldg has multiple properties
# 2411722420141
# 2411722420141
# 1811921240048
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 527 Marquette Ave: 22-029-24-44-0060
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 425 7th St S: 22-029-24-31-0047
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 901 Nicollet Mallyoung Quinlan Bldg: 27-029-24-12-0099
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 3737 3rd Ave S
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 100 6th St N has multiple properties
# 1811921240050
# 1811921240050
# 1311922110022
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 2701 Wells Fargo Way: 34-029-24-41-0104
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 110 5th St N has multiple properties
# 2411722420010
# 2411722420010
# 2302924410210
# 2202924420114
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 3001 Broadway St Ne: 18-029-23-24-0008
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 2512 7th St S: 25-029-24-42-0068
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 900 Nicollet Mall #h has multiple properties
# 2702924120181
# 2702924120181
# 2702924120183
# 2702924120184
# 2702924120182
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 814 9th St S has multiple properties
# 2511722310623
# 2511722310623
# 2511722310622
# 2511722310621
# 2511722310620
# 2511722310627
# 2511722310626
# 2511722310625
# 2511722310624
# 2602924240124
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 401 2nd Ave S has multiple properties
# 1811921220101
# 1811921220101
# 2302924330775
# 2202924130526
# 2202924130401
# 2202924130410
# 2202924130499
# 2202924130500
# 2202924130501
# 2202924130502
# 2202924130503
# 2202924130504
# 2202924130505
# 2202924130506
# 2202924130507
# 2202924130508
# 2202924130411
# 2202924130509
# 2202924130510
# 2202924130511
# 2202924130512
# 2202924130513
# 2202924130514
# 2202924130515
# 2202924130516
# 2202924130517
# 2202924130518
# 2202924130412
# 2202924130519
# 2202924130520
# 2202924130521
# 2202924130522
# 2202924130523
# 2202924130524
# 2202924130525
# 2202924130527
# 2202924130528
# 2202924130413
# 2202924130529
# 2202924130530
# 2202924130531
# 2202924130532
# 2202924130533
# 2202924130534
# 2202924130535
# 2202924130536
# 2202924130537
# 2202924130538
# 2202924130414
# 2202924130539
# 2202924130540
# 2202924130541
# 2202924130542
# 2202924130543
# 2202924130544
# 2202924130545
# 2202924130546
# 2202924130547
# 2202924130548
# 2202924130415
# 2202924130549
# 2202924130550
# 2202924130551
# 2202924130552
# 2202924130553
# 2202924130554
# 2202924130555
# 2202924130556
# 2202924130557
# 2202924130558
# 2202924130416
# 2202924130559
# 2202924130560
# 2202924130561
# 2202924130562
# 2202924130563
# 2202924130564
# 2202924130565
# 2202924130566
# 2202924130567
# 2202924130568
# 2202924130417
# 2202924130569
# 2202924130570
# 2202924130571
# 2202924130572
# 2202924130573
# 2202924130574
# 2202924130575
# 2202924130576
# 2202924130577
# 2202924130578
# 2202924130418
# 2202924130579
# 2202924130580
# 2202924130581
# 2202924130582
# 2202924130583
# 2202924130584
# 2202924130585
# 2202924130586
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 80 8th St S
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 50 6th St S has multiple properties
# 2411722430037
# 2411722430037
# 2202924440110
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 704 4th Ave S
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 600 1st Ave N has multiple properties
# 2202924430142
# 2202924430142
# 1811921220148
# 1311922110132
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 800 Nicollet Mall: 27-029-24-12-0139
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 501 Nicollet Mall #j has multiple properties
# 2202924440111
# 2202924440111
# 2202924440112
# 2202924440113
# 2202924440114
# 2202924440115
# 2202924440116
# 2202924440117
# 2202924440118
# 2202924440119
# 2202924440120
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 222 9th St S has multiple properties
# 2411722240007
# 2411722240007
# 2702924110093
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 353 5th St N: 22-029-24-31-0066
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 707 2nd Ave S -american Express Headquarter: 27-029-24-11-0133
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 901 3rd Ave S has multiple properties
# 2702924140084
# 2702924140084
# 2202924210265
# 2202924210266
# 2202924210268
# 2202924210269
# 2202924210270
# 2202924210271
# 2202924210273
# 2202924210274
# 2202924210307
# 2202924210316
# 2202924210317
# 2202924210318
# 2202924210319
# 2202924210320
# 2202924210321
# 2202924210322
# 2202924210323
# 2202924210324
# 2202924210325
# 2202924210308
# 2202924210326
# 2202924210327
# 2202924210328
# 2202924210329
# 2202924210330
# 2202924210331
# 2202924210332
# 2202924210333
# 2202924210334
# 2202924210335
# 2202924210309
# 2202924210336
# 2202924210337
# 2202924210338
# 2202924210339
# 2202924210340
# 2202924210341
# 2202924210342
# 2202924210343
# 2202924210344
# 2202924210345
# 2202924210310
# 2202924210346
# 2202924210347
# 2202924210348
# 2202924210349
# 2202924210311
# 2202924210312
# 2202924210313
# 2202924210314
# 2202924210315
# 2202924210275
# 2202924210276
# 2202924210277
# 2202924210278
# 2202924210279
# 2202924210280
# 2202924210281
# 2202924210282
# 2202924210283
# 2202924210284
# 2202924210285
# 2202924210286
# 2202924210287
# 2202924210288
# 2202924210289
# 2202924210290
# 2202924210291
# 2202924210292
# 2202924210293
# 2202924210294
# 2202924210295
# 2202924210296
# 2202924210297
# 2202924210298
# 2202924210299
# 2202924210300
# 2202924210301
# 2202924210302
# 2202924210303
# 2202924210304
# 2202924210305
# 2202924210306
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 200 6th St S has multiple properties
# 2302924410011
# 2302924410011
# 1402924430211
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 420 5Th St N has multiple properties
# 2202924420035
# 2202924420035
# 2302924140033
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 225 6th St S has multiple properties
# 2411722130025
# 2411722130025
# 1811921240107
# 1811921310058
# 1311922110101
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 250 Marquette Ave: 22-029-24-41-0012
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 33 S 6th St
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 425 S 2nd St
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 600 Hennepin Ave has multiple properties
# 2202924430186
# 2202924430186
# 2302924110037
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 801 21st Ave S: 16-029-24-14-0088
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 2016 8th St
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 720 22nd Ave S
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 625 22nd Ave S
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 715 20th Ave S
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 715 23rs Ave S
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 801 21st Ave S: 16-029-24-14-0088
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 90 7th St S: 27-029-24-11-0012
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 2701 Elliot Ave: 35-029-24-31-0114
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 920 2nd Ave S: 24-029-24-32-0082
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 330 University Ave SE
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 717 Marquette Ave - Investors Bldg: 27-029-24-11-0006
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 501 4th Ave S has multiple properties
# 1811921220034
# 1811921220034
# 2602924220353
# 1402924340025
# 2602924220434
# 2302924140028
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 3701 Wayzata Blvd: 29-029-24-32-0004
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 601 1st Ave N has multiple properties
# 2202924430185
# 2202924430185
# 1311922110126
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 17 7th St S has multiple properties
# 2411722420036
# 2411722420036
# 1811921240057
# 1811921310092
# 2202924430086
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 730 2nd Ave S: 27-029-24-11-0007
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 111 Washington S
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 2430 3rd Ave S
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 100 Washington Ave S has multiple properties
# 2711723240105
# 2711723240105
# 2202924410049
# 2302924320012
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 121 8th St S
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 800 Lasalle Ave Ste # 1040: 27-029-24-12-0125
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 608 2nd Ave S has multiple properties
# 1811921220081
# 1811921220081
# 1311922110003
# 2702924110099
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 120 6th St S: 22-029-24-44-0063
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 412 3rd St S has multiple properties
# 1402924430144
# 1402924430144
# 2302924340717
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 30 7th St S -marriott Hotel has multiple properties
# 2411722420044
# 2411722420044
# 2202924430119
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 100 5th St S has multiple properties
# 1811921240005
# 1811921240005
# 2302924120077
# 2202924440100
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 2414 7th St S: 25-029-24-42-0074
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 1000 Nicollet Mall: 27-029-24-12-0137
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 255 2nd Ave S: 23-029-24-33-0046
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 2525 Chicago Ave: 35-029-24-24-0372
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 1001 Marquette Ave: 27-029-24-13-0278
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 910 Lasalle Ave: 27-029-24-12-0085
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 25 1st St N: 22-029-24-41-0139
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 5025 Knox Ave S: 16-028-24-31-0077
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 15 5th St S: 22-029-24-44-0054
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 2751 Elliot Ave
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 2215 Park Ave: 35-029-24-22-0100
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 100 2nd Ave N has multiple properties
# 2202924140204
# 2202924140204
# 1811921230017
# 1811921320040
# 2302924210476
# 2302924210477
# 2302924210478
# 2302924210479
# 2302924210480
# 2302924210481
# 2302924210482
# 2302924210483
# 2302924210484
# Exception on 100 2nd Ave N
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 416 10th St S has multiple properties
# 2202924220017
# 2202924220017
# 2702924140029
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 333 Washington Ave N: 22-029-24-13-1162
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 1936 Lyndale Ave S: 28-029-24-44-0005
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 277 12th Ave N: 22-029-24-21-0080
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 1635 Hennepin Ave: 27-029-24-23-0035
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Exception on 1130 Nicollet Mall
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 2540 Park Ave: 35-029-24-23-0012
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 300 1st Ave N has multiple properties
# 2202924410126
# 2202924410126
# 1311922140093
# 2202924140008
# 2202924140009
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 2450 Riverside Ave
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 1010 Currie Ave: 22-029-24-34-0058
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 702 1st St N has multiple properties
# 2202924120106
# 2202924120106
# 2202924120120
# 2202924120121
# 2202924120033
# 2202924120034
# 2202924120037
# 2202924120038
# 2202924120031
# 2202924120032
# 2202924120035
# 2202924120036
# 2202924120042
# 2202924120045
# 2202924120046
# 2202924120411
# 2202924120043
# 2202924120044
# 2202924120418
# 2202924120050
# 2202924120412
# Exception on 702 1st St N
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 10 2nd St NE: 23-029-24-24-0095
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 921 Marquette Ave has multiple properties
# 2702924110024
# 2702924110024
# 2702924110025
# 1402924320144
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 10 Lake St W has multiple properties
# 3402924430141
# 3402924430141
# 2711723230093
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 2800 Wayzata Blvd: 29-029-24-13-0016
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 45 8th St S #F has multiple properties
# 2702924120116
# 2702924120116
# 2702924120185
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 511 Groveland Ave: 27-029-24-33-0740
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 90 11th St S
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 3033 Excelsior Blvd: 05-028-24-12-0005
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 525 2nd St N has multiple properties
# 1811921220093
# 1811921220093
# 1311922110038
# 1811921240119
# 1811921310024
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 2025 East River Pkwy
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 710 24th St E: 35-029-24-22-0099
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 312 3rd St S has multiple properties
# 2302924120178
# 2302924120178
# 2302924140070
# 2302924330027
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 122 Franklin Ave W: 27-029-24-34-0070
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 630 22Nd Ave S: 25-029-24-31-0100
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 700 Dunwoody Blvd/Wayzata Blvd
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 2324 Emerson Ave S: 16-029-24-12-0184
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 2701 University SE has multiple properties
# 1102924210015
# 1102924210015
# 3002923130048
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 404 8Th St S has multiple properties
# 2602924220084
# 2602924220084
# 2402924220015
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Exception on 720 13Th Ave S
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 3335 Blaisdell Ave: 03-028-24-24-0197
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 901 Hennepin Ave: 27-029-24-12-0005
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 1101 River Pkwy W has multiple properties
# 3002923340074
# 3002923340074
# 2302924440021
# 2102724430071
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 46 S 11th St
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 825 8th St S: 26-029-24-24-0113
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 212 9th Ave S: 23-029-24-43-0195
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 708 2Nd St S has multiple properties
# 3511723230025
# 3511723230025
# 2302924430055
# 2302924430056
# 2302924430057
# 2302924430058
# 2302924430059
# 2302924430060
# 2302924430061
# 2302924430062
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 100 1St Ave N has multiple properties
# 2202924140062
# 2202924140062
# 2302924210092
# 2202924140052
# 1811921230045
# 2302924320542
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 1600 Buchanan St: 13-029-24-21-0083
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 45 7Th St S Suite 200 has multiple properties
# 1502924440056
# 1502924440056
# 2411722430046
# 2202924430213
# 2202924430214
# 2202924430215
# 2202924430216
# 2202924430217
# 2202924430218
# 2202924430219
# 2202924430220
# 2202924430221
# 2202924430222
# 2202924430223
# 2202924430224
# 2202924430225
# 2202924430226
# 2202924430227
# 2202924430228
# 2202924430229
# 2202924430230
# 2202924430231
# 2202924430232
# 2202924430233
# 2202924430234
# 2202924430235
# 2202924430236
# 2202924430237
# 2202924430238
# 2202924430239
# 2202924430240
# 2202924430241
# 2202924430242
# 2202924430243
# 2202924430244
# 2202924430245
# 2202924430246
# 2202924430247
# 2202924430248
# 2202924430249
# 2202924430250
# 2202924430251
# 2202924430252
# 2202924430253
# 2202924430254
# 2202924430255
# 2202924430256
# 2202924430257
# 2202924430258
# 2202924430259
# 2202924430260
# 2202924430261
# 2202924430262
# 2202924430263
# 2202924430264
# 2202924430265
# 2202924430266
# 2202924430267
# 2202924430268
# 2202924430269
# 2202924430270
# 2202924430271
# 2202924430272
# 2202924430273
# 2202924430274
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 15 9th St S has multiple properties
# 2411722420074
# 2411722420074
# 2411722430153
# 2702924120002
# 2702924120003
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 625 2nd Ave S has multiple properties
# 3511723230010
# 3511723230010
# 1811921220087
# 1311922110107
# 2702924110031
# 2202924130220
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 811 Lasalle Ave: 27-029-24-12-0144
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 4999 France Ave S: 17-028-24-23-0157
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 701 Broadway W: 18-119-21-31-0003
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 101 4th St SE has multiple properties
# 1811921320041
# 1811921320041
# 1311922110027
# 2302924120006
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 405 8th St S: 26-029-24-23-0001
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 511 Kenwood Pkwy
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Exception on 2121 Lake St E -ymca
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 711 Hennepin Ave: 22-029-24-43-0149
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 2430 3rd Ave S
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 701 Washington Ave N: 22-029-24-13-0046
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 810 Glenwood Ave N has multiple properties
# 0511722140018
# 0511722140018
# 2102924440051
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 500 Washington Ave S -depot Office Center has multiple properties
# 2202924130061
# 2202924130061
# 2302924340389
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 616 24th Ave S: 25-029-24-31-0051
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 409 Marquette Ave: 22-029-24-44-0028
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 2500 6th St S: 25-029-24-42-0066
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 301 4th Ave S has multiple properties
# 2302924330041
# 2302924330041
# 1402924430118
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 2220 Riverside Ave
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 615 1st Ave NE -River Station has multiple properties
# 2302924120189
# 2302924120189
# 1311922110131
# 2202924120294
# 2202924120295
# 2202924120296
# 2202924120297
# 2202924120298
# 2202924120299
# 2202924120300
# 2202924120301
# 2202924120302
# 2202924120303
# 2202924120304
# 2202924120305
# 2202924120306
# 2202924120307
# 2202924120308
# 2202924120309
# 2202924120310
# 2202924120311
# 2202924120312
# 2202924120313
# 2202924120314
# 2202924120315
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 331 2nd Ave S has multiple properties
# 2302924330685
# 2302924330685
# 1402924340078
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 1220 Marshall St -brew House: 15-029-24-14-0102
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 900 Nicollet Mall #c has multiple properties
# 2702924120181
# 2702924120181
# 2702924120183
# 2702924120184
# 2702924120182
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 729 2nd Ave
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 414 Nicollet Mall: 22-029-24-44-0015
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 510 1st Ave Nbutler North Building
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 2929 Chicago Ave has multiple properties
# 3502924340620
# 3502924340620
# 3502924340629
# 3502924340719
# 3502924340720
# 3502924340721
# 3502924340722
# 3502924340723
# 3502924340724
# 3502924340725
# 3502924340726
# 3502924340727
# 3502924340728
# 3502924340630
# 3502924340729
# 3502924340730
# 3502924340731
# 3502924340732
# 3502924340733
# 3502924340734
# 3502924340735
# 3502924340736
# 3502924340737
# 3502924340738
# 3502924340631
# 3502924340739
# 3502924340740
# 3502924340741
# 3502924340742
# 3502924340743
# 3502924340744
# 3502924340745
# 3502924340746
# 3502924340747
# 3502924340748
# 3502924340632
# 3502924340749
# 3502924340750
# 3502924340751
# 3502924340633
# 3502924340634
# 3502924340635
# 3502924340636
# 3502924340637
# 3502924340638
# 3502924340621
# 3502924340639
# 3502924340640
# 3502924340641
# 3502924340642
# 3502924340643
# 3502924340644
# 3502924340645
# 3502924340646
# 3502924340647
# 3502924340648
# 3502924340622
# 3502924340649
# 3502924340650
# 3502924340651
# Exception on 2929 Chicago Ave
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 2501 Stevens Ave S
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 913 26Th St E
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 1107 Harmon Pl Mpls: 27-029-24-21-0211
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 3660 Technology Dr: 03-029-24-21-0025
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 1540 New Brighton Blvd: 13-029-24-11-0031
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 501 Nicollet Mall #D has multiple properties
# 2202924440111
# 2202924440111
# 2202924440112
# 2202924440113
# 2202924440114
# 2202924440115
# 2202924440116
# 2202924440117
# 2202924440118
# 2202924440119
# 2202924440120
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 4225 3rd Ave S: 10-028-24-41-0002
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 606 24th Ave S -Fairview St Marys Bldg: 25-029-24-31-0006
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 119 4th St N has multiple properties
# 2202924420079
# 2202924420079
# 2302924130064
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 2500 Lake St E has multiple properties
# 3202924140020
# 3202924140020
# 3302924240066
# 3602924430084
# 3202924440011
# 2411724210005
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 1520 New Brighton Blvd -home Depot: 13-029-24-12-0016
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 16 9th St S #1 has multiple properties
# 2411722310127
# 2411722310127
# 2411722340119
# 2702924120186
# 2702924120131
# 2702924120187
# 2702924120133
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 900 4th St N has multiple properties
# 2102924410035
# 2102924410035
# 2202924210432
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 610 22nd Ave S has multiple properties
# 1502924230058
# 1502924230058
# 3502924220123
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 1615 River Rd W has multiple properties
# 3102923120023
# 3102923120023
# 3102923120004
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 2530 Chicago Ave: 35-029-24-23-0180
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 2101 Summer St: 13-029-24-41-0035
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 400 2nd Ave S has multiple properties
# 2202924420067
# 2202924420067
# 1811921220071
# 2202924440030
# 1402924340153
# 2302924410216
# 1811921310100
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 401 3rd St N has multiple properties
# 2302924330043
# 2302924330043
# 2202924130017
# 2202924131164
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 1750 Hennepin Ave: 28-029-24-41-0048
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 1650 New Brighton Blvd
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 3200 Lake St W: 22-117-24-33-0001
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 528 Hennepin Ave
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 706 2nd Ave S -baker Building: 27-029-24-11-0004
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 2021 Hennepin Ave E: 18-029-23-33-0046
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 310 4th Ave S has multiple properties
# 2302924330035
# 2302924330035
# 2302924140116
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# 1012 Lasalle Ave #B has multiple properties
# 2702924120189
# 2702924120189
# 2702924120190
# 2702924120191
# 2702924120192
# 2702924120193
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 2500 3rd Ave S: 34-029-24-13-0053
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 910 Elliot Ave: 26-029-24-31-0101
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# Found 2840 4th Ave S: 34-029-24-44-0160
# http://www16.co.hennepin.mn.us/pins/addrresult.jsp
# No records found for 3433 Broadway St NE

# %%
#41 of 258 private properties were not found
import pickle

with open('0201_private_prop_dict.pkl', 'wb') as picklefile:
    pickle.dump(private_property_info, picklefile)

# %%
clean_addresses(public_df)
public_df.sample(5)
# Out:
#                          Organization Name  \
# 77   Minneapolis Park and Recreation Board
# 134             Minneapolis Public Schools
# 91   Minneapolis Park and Recreation Board
# 59   Minneapolis Park and Recreation Board
# 96              Minneapolis Public Schools
#
#                               Property Name              Address  Postal Code  \
# 77   Northeast Park - Demolished [Mn012187]  1616 Buchanon St NE        55413
# 134                       North Senior High     1500 James Ave N        55411
# 91                    Waite Park [Mn012200]     1810 34th Ave NE        55418
# 59                Keewaydin Park [Mn012169]       3030 53rd St E        55417
# 96                      Andersen Elementary      2727 10th Ave S        55407
#
#      ENERGY STAR Score                  Primary Property Type  \
# 77                   0  Other - Entertainment/Public Assembly
# 134                  8                            K-12 School
# 91                   0  Other - Entertainment/Public Assembly
# 59                   0  Other - Entertainment/Public Assembly
# 96                  41                            K-12 School
#
#      Floor Area (Buildings) (ft²)  Floor Area (Parking) (ft²)  Year Built  \
# 77                              0                           0        1970
# 134                        290000                           0        1972
# 91                           6212                           0        1979
# 59                           6314                           0        1972
# 96                         233557                           0        1976
#
#      Total GHG Emissions (Metric Tons CO2e)  Site EUI (kBtu/ft²)  \
# 77                                        0                    0
# 134                                    3888                  125
# 91                                       47                   58
# 59                                       79                  127
# 96                                      538                   79
#
#      Weather Normalized Site EUI (kBtu/ft²)  Source EUI (kBtu/ft²)  \
# 77                                        0                      0
# 134                                     131                    224
# 91                                       61                    123
# 59                                      137                    213
# 96                                       83                    156
#
#      Weather Normalized Source EUI (kBtu/ft²)  Water Use (kgal)  Unnamed: 15  \
# 77                                          0                 0          NaN
# 134                                       231              5118          NaN
# 91                                        127                 0          NaN
# 59                                        224                 0          NaN
# 96                                        161              3381          NaN
#
#           search_address
# 77   1616 Buchanon St NE
# 134     1500 James Ave N
# 91      1810 34th Ave NE
# 59        3030 53rd St E
# 96       2727 10th Ave S

# %%
public_property_info = run_scraper(public_df)

# %%
private_df.head()
# Out:
#               Address Postal Code  ENERGY STAR Score Primary Property Type  \
# 0   201 Chicago Ave S       55415                 36                Office
# 1  1011 Nicollet Mall       55403                 68                Office
# 2    4701 Beard Ave S       55410                  0                 Other
# 3         8 60Th St W       55419                 76      Worship Facility
# 4      700 10Th Ave S       55415                 89                Office
#
#    Floor Area (Building) (ft²)  Floor Area (Parking) (ft²)  Year Built  \
# 0                        62400                           0        2012
# 1                        59479                           0        1920
# 2                        59172                           0        1914
# 3                        60640                       62000        1959
# 4                        60528                           0        1920
#
#    Total GHG Emissions (Metric Tons CO2e)  Site EUI (kBtu/ft²)  \
# 0                                     971                  115
# 1                                     986                   90
# 2                                    1622                  157
# 3                                     268                   50
# 4                                     504                   74
#
#    Weather Normalized Site EUI (kBtu/ft²)  Source EUI (kBtu/ft²)  \
# 0                                     118                    251
# 1                                      93                    256
# 2                                     160                    427
# 3                                      54                     77
# 4                                      77                    136
#
#    Weather Normalized Source EUI (kBtu/ft²)  Water Use (kgal)  Unnamed: 13
# 0                                       252               708          NaN
# 1                                       266               882          NaN
# 2                                       428               163          NaN
# 3                                        81               674          NaN
# 4                                       140               414          NaN
