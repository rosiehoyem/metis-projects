# %%
# Python 2 & 3 Compatibility
from __future__ import print_function, division

# Necessary imports
import pandas as pd
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
import patsy
import seaborn as sns
from seaborn import plt
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import RidgeCV

# %matplotlib inline

# %%
from dbfread import DBF

# %%
# This file is too large to track in this Github repo

table = DBF('../data/raw/hennepin_county_metrogis_parcels/hennepin_county_metrogis_parcels.dbf', load=True, raw=True)

# %%
cols = table.field_names
cols
# Out:
# ['COUNTY_ID',
#  'PIN',
#  'BLDG_NUM',
#  'PREFIX_DIR',
#  'PREFIXTYPE',
#  'STREETNAME',
#  'STREETTYPE',
#  'SUFFIX_DIR',
#  'UNIT_INFO',
#  'CITY',
#  'CITY_USPS',
#  'ZIP',
#  'ZIP4',
#  'PLAT_NAME',
#  'BLOCK',
#  'LOT',
#  'ACRES_POLY',
#  'ACRES_DEED',
#  'USE1_DESC',
#  'USE2_DESC',
#  'USE3_DESC',
#  'USE4_DESC',
#  'MULTI_USES',
#  'LANDMARK',
#  'OWNER_NAME',
#  'OWNER_MORE',
#  'OWN_ADD_L1',
#  'OWN_ADD_L2',
#  'OWN_ADD_L3',
#  'TAX_NAME',
#  'TAX_ADD_L1',
#  'TAX_ADD_L2',
#  'TAX_ADD_L3',
#  'HOMESTEAD',
#  'EMV_LAND',
#  'EMV_BLDG',
#  'EMV_TOTAL',
#  'TAX_CAPAC',
#  'TOTAL_TAX',
#  'SPEC_ASSES',
#  'TAX_EXEMPT',
#  'XUSE1_DESC',
#  'XUSE2_DESC',
#  'XUSE3_DESC',
#  'XUSE4_DESC',
#  'DWELL_TYPE',
#  'HOME_STYLE',
#  'FIN_SQ_FT',
#  'GARAGE',
#  'GARAGESQFT',
#  'BASEMENT',
#  'HEATING',
#  'COOLING',
#  'YEAR_BUILT',
#  'NUM_UNITS',
#  'SALE_DATE',
#  'SALE_VALUE',
#  'SCHOOL_DST',
#  'WSHD_DIST',
#  'GREEN_ACRE',
#  'OPEN_SPACE',
#  'AG_PRESERV',
#  'AGPRE_ENRD',
#  'AGPRE_EXPD',
#  'PARC_CODE',
#  'Shape_area',
#  'Shape_len']

# %%
# create a dataframe

df = pd.DataFrame(table.records)

# %%
df.sample(5)
# Out:
#        COUNTY_ID                   PIN       BLDG_NUM PREFIX_DIR PREFIXTYPE  \
# 18632     b'053'  b'053-3402924240224'  b'2500      '      b'  '  b'      '
# 104900    b'053'  b'053-3411922330070'  b'6268      '      b'  '  b'      '
# 373980    b'053'  b'053-2711823330014'  b'1003      '      b'  '  b'      '
# 421483    b'053'  b'053-1102924440143'  b'1828      '      b'  '  b'      '
# 378237    b'053'  b'053-0302824420139'  b'3500      '      b'  '  b'      '
#
#                                          STREETNAME STREETTYPE SUFFIX_DIR  \
# 18632   b'BLAISDELL AVE S                         '    b'    '      b'  '
# 104900  b'EMPIRE LA N                             '    b'    '      b'  '
# 373980  b'COX FARM RD                             '    b'    '      b'  '
# 421483  b'QUINCY ST N E                           '    b'    '      b'  '
# 378237  b'STEVENS AVE S                           '    b'    '      b'  '
#
#               UNIT_INFO                               CITY  \
# 18632   b'202         '  b'MINNEAPOLIS                   '
# 104900  b'            '  b'MAPLE GROVE                   '
# 373980  b'            '  b'ORONO                         '
# 421483  b'            '  b'MINNEAPOLIS                   '
# 378237  b'            '  b'MINNEAPOLIS                   '
#
#                  ...           SCHOOL_DST  \
# 18632            ...            b'001   '
# 104900           ...            b'279   '
# 373980           ...            b'278   '
# 421483           ...            b'001   '
# 378237           ...            b'001   '
#
#                                                 WSHD_DIST GREEN_ACRE  \
# 18632   b'Middle Mississippi                          ...       b'N'
# 104900  b'Lower Minnesota River                       ...       b'N'
# 373980  b'Minnehaha Creek                             ...       b'N'
# 421483  b'Middle Mississippi                          ...       b'N'
# 378237  b'Middle Mississippi                          ...       b'N'
#
#        OPEN_SPACE AG_PRESERV   AGPRE_ENRD   AGPRE_EXPD PARC_CODE  \
# 18632        b'N'       b'N'  b'        '  b'        '  b'    0'
# 104900       b'N'       b'N'  b'        '  b'        '  b'    0'
# 373980       b'N'       b'N'  b'        '  b'        '  b'    0'
# 421483       b'N'       b'N'  b'        '  b'        '  b'    0'
# 378237       b'N'       b'N'  b'        '  b'        '  b'    0'
#
#                     Shape_area               Shape_len
# 18632   b' 3.00064830874e+003'  b' 2.19955517527e+002'
# 104900  b' 1.09068264126e+003'  b' 1.33445617621e+002'
# 373980  b' 8.10613777143e+003'  b' 3.64894065657e+002'
# 421483  b' 4.31402800650e+002'  b' 9.20192597310e+001'
# 378237  b' 3.76159905025e+002'  b' 8.10102390853e+001'
#
# [5 rows x 67 columns]

# %%
df.shape
# Out:
# (429570, 67)

# %%
# Turn the table from binary to a utf-8 encoded string

def decode_binary(df, cols):
    decode = lambda x : x.decode('utf-8')
    for col in cols:
        df[col] = df[col].apply(decode)

# %%
decode_binary(df, cols)
df.head()
# Out:
#   COUNTY_ID                PIN    BLDG_NUM PREFIX_DIR PREFIXTYPE  \
# 0       053  053-0911821410021  54
# 1       053  053-1311821120005  4400 1/2
# 2       053  053-1311724440113  2325
# 3       053  053-2911821440091  28
# 4       053  053-0111823440003  80
#
#                                  STREETNAME STREETTYPE SUFFIX_DIR  \
# 0  ADDRESS UNASSIGNED
# 1  LYNDALE AVE N
# 2  MONTCLAIR LA
# 3  ADDRESS UNASSIGNED
# 4  ADDRESS UNASSIGNED
#
#       UNIT_INFO                            CITY         ...           \
# 0                CRYSTAL                                ...
# 1                MINNEAPOLIS                            ...
# 2                MOUND                                  ...
# 3                GOLDEN VALLEY                          ...
# 4                MEDINA                                 ...
#
#   SCHOOL_DST                                          WSHD_DIST GREEN_ACRE  \
# 0     281     Shingle Creek                                 ...          N
# 1     001     Shingle Creek                                 ...          N
# 2                                                           ...          N
# 3     281     Bassett Creek                                 ...          N
# 4     284                                                   ...          N
#
#   OPEN_SPACE AG_PRESERV AGPRE_ENRD AGPRE_EXPD PARC_CODE           Shape_area  \
# 0          N          N                               0   7.25247600000e-002
# 1          N          N                               0   7.25380050000e-002
# 2          N          N                               0   7.25352550000e-002
# 3          N          N                               0   7.25358400000e-002
# 4          N          N                               0   7.25419200000e-002
#
#              Shape_len
# 0   9.55874206426e-001
# 1   9.55961240593e-001
# 2   9.55943566274e-001
# 3   9.55947921559e-001
# 4   9.55987121801e-001
#
# [5 rows x 67 columns]

# %%
# Remove white space from around the entries

def strip_entries(df, cols):
    strip = lambda x : x.strip()
    for col in cols:
        df[col] = df[col].apply(strip)

# %%
# Remove the county code and dash from the property IDs

def remove_dash(df, cols):
    x_dash = lambda x : x.split('-')[1] if '-' in x else x
    for col in cols:
        df[col] = df[col].apply(x_dash)

# %%
strip_entries(df, cols)

# %%
remove_dash(df, cols)

# %%
df.head()
# Out:
#   COUNTY_ID            PIN  BLDG_NUM PREFIX_DIR PREFIXTYPE  \
# 0       053  0911821410021        54
# 1       053  1311821120005  4400 1/2
# 2       053  1311724440113      2325
# 3       053  2911821440091        28
# 4       053  0111823440003        80
#
#            STREETNAME STREETTYPE SUFFIX_DIR UNIT_INFO           CITY  \
# 0  ADDRESS UNASSIGNED                                        CRYSTAL
# 1       LYNDALE AVE N                                    MINNEAPOLIS
# 2        MONTCLAIR LA                                          MOUND
# 3  ADDRESS UNASSIGNED                                  GOLDEN VALLEY
# 4  ADDRESS UNASSIGNED                                         MEDINA
#
#      ...    SCHOOL_DST      WSHD_DIST GREEN_ACRE OPEN_SPACE AG_PRESERV  \
# 0    ...           281  Shingle Creek          N          N          N
# 1    ...           001  Shingle Creek          N          N          N
# 2    ...                                       N          N          N
# 3    ...           281  Bassett Creek          N          N          N
# 4    ...           284                         N          N          N
#
#   AGPRE_ENRD AGPRE_EXPD PARC_CODE Shape_area Shape_len
# 0                               0        002       001
# 1                               0        002       001
# 2                               0        002       001
# 3                               0        002       001
# 4                               0        002       001
#
# [5 rows x 67 columns]

# %%
# Remove empty strings

def replace_empty_values(df):
    df_cl = df.replace(r'\s+', np.nan, regex=True)
    df_cl = df.replace('', np.nan)
    return df_cl

df = replace_empty_values(df)

# %%
df.head()
# Out:
#   COUNTY_ID            PIN  BLDG_NUM  PREFIX_DIR  PREFIXTYPE  \
# 0       053  0911821410021        54         NaN         NaN
# 1       053  1311821120005  4400 1/2         NaN         NaN
# 2       053  1311724440113      2325         NaN         NaN
# 3       053  2911821440091        28         NaN         NaN
# 4       053  0111823440003        80         NaN         NaN
#
#            STREETNAME  STREETTYPE  SUFFIX_DIR UNIT_INFO           CITY  \
# 0  ADDRESS UNASSIGNED         NaN         NaN       NaN        CRYSTAL
# 1       LYNDALE AVE N         NaN         NaN       NaN    MINNEAPOLIS
# 2        MONTCLAIR LA         NaN         NaN       NaN          MOUND
# 3  ADDRESS UNASSIGNED         NaN         NaN       NaN  GOLDEN VALLEY
# 4  ADDRESS UNASSIGNED         NaN         NaN       NaN         MEDINA
#
#      ...    SCHOOL_DST      WSHD_DIST  GREEN_ACRE OPEN_SPACE AG_PRESERV  \
# 0    ...           281  Shingle Creek           N          N          N
# 1    ...           001  Shingle Creek           N          N          N
# 2    ...           NaN            NaN           N          N          N
# 3    ...           281  Bassett Creek           N          N          N
# 4    ...           284            NaN           N          N          N
#
#   AGPRE_ENRD AGPRE_EXPD PARC_CODE Shape_area Shape_len
# 0        NaN        NaN         0        002       001
# 1        NaN        NaN         0        002       001
# 2        NaN        NaN         0        002       001
# 3        NaN        NaN         0        002       001
# 4        NaN        NaN         0        002       001
#
# [5 rows x 67 columns]

# %%
# convert sale date to date object
import time

def convert_date(df):
    convert = lambda x : time.strptime(x, "%Y%m%d") if type(x) == str else np.nan
    df['sale_date_object'].apply(convert)
    
df['sale_date_object'] = df['SALE_DATE']

convert_date(df)

# %%
df['SALE_VALUE'].replace('[\$,)]','', inplace=True, regex=True)
df['SALE_VALUE'] = df['SALE_VALUE'].astype(float, copy=False)

df['YEAR_BUILT'] = df['YEAR_BUILT'].astype(int, copy=False)

# %%
df['FIN_SQ_FT'] = df['FIN_SQ_FT'].astype(int, copy=False)
df['EMV_LAND'] = df['EMV_LAND'].astype(float, copy=False)
df['EMV_BLDG'] = df['EMV_BLDG'].astype(float, copy=False)
df['EMV_TOTAL'] = df['EMV_TOTAL'].astype(float, copy=False)
df['TOTAL_TAX'] = df['TOTAL_TAX'].astype(float, copy=False)
df['TAX_CAPAC'] = df['TAX_CAPAC'].astype(float, copy=False)
df['SCHOOL_DST'] = df['SCHOOL_DST'].astype(float, copy=False)

# %%
df['cost_per_sqft'] = df['SALE_VALUE'] / df['FIN_SQ_FT']

# %%
df.head()
# Out:
#   COUNTY_ID            PIN  BLDG_NUM  PREFIX_DIR  PREFIXTYPE  \
# 0       053  0911821410021        54         NaN         NaN
# 1       053  1311821120005  4400 1/2         NaN         NaN
# 2       053  1311724440113      2325         NaN         NaN
# 3       053  2911821440091        28         NaN         NaN
# 4       053  0111823440003        80         NaN         NaN
#
#            STREETNAME  STREETTYPE  SUFFIX_DIR UNIT_INFO           CITY  \
# 0  ADDRESS UNASSIGNED         NaN         NaN       NaN        CRYSTAL
# 1       LYNDALE AVE N         NaN         NaN       NaN    MINNEAPOLIS
# 2        MONTCLAIR LA         NaN         NaN       NaN          MOUND
# 3  ADDRESS UNASSIGNED         NaN         NaN       NaN  GOLDEN VALLEY
# 4  ADDRESS UNASSIGNED         NaN         NaN       NaN         MEDINA
#
#        ...      GREEN_ACRE OPEN_SPACE  AG_PRESERV AGPRE_ENRD AGPRE_EXPD  \
# 0      ...               N          N           N        NaN        NaN
# 1      ...               N          N           N        NaN        NaN
# 2      ...               N          N           N        NaN        NaN
# 3      ...               N          N           N        NaN        NaN
# 4      ...               N          N           N        NaN        NaN
#
#   PARC_CODE Shape_area Shape_len sale_date_object cost_per_sqft
# 0         0        002       001              NaN           NaN
# 1         0        002       001              NaN           NaN
# 2         0        002       001              NaN           NaN
# 3         0        002       001              NaN           NaN
# 4         0        002       001              NaN           NaN
#
# [5 rows x 69 columns]

# %%
df_mpls = df[df['CITY'] == "MINNEAPOLIS"]

# %%
len(df_mpls)
# Out:
# 129719

# %%
# Extracted only the columns I want to use for this analysis

sub_cols = ['PIN', 'USE1_DESC','EMV_TOTAL', 'TAX_CAPAC', 'TOTAL_TAX', 'FIN_SQ_FT', 'YEAR_BUILT']
df_subset = df_mpls[sub_cols]

# %%
df_subset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 129719 entries, 1 to 429557
# Data columns (total 7 columns):
# PIN           129719 non-null object
# USE1_DESC     129718 non-null object
# EMV_TOTAL     129719 non-null float64
# TAX_CAPAC     129719 non-null float64
# TOTAL_TAX     129719 non-null float64
# FIN_SQ_FT     129719 non-null int64
# YEAR_BUILT    129719 non-null int64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 7.9+ MB

# %%
df_subset.head()
# Out:
#               PIN     USE1_DESC  EMV_TOTAL  TAX_CAPAC  TOTAL_TAX  FIN_SQ_FT  \
# 1   1311821120005    Commercial        0.0        0.0        0.0          0
# 12  3502924230001    Commercial        0.0        0.0        0.0          0
# 13  0202824230266           NaN        0.0        0.0        0.0          0
# 14  0902924420203   Residential      500.0        6.0        9.0          0
# 15  0902924420198   Residential    61500.0      615.0      978.0          0
#
#     YEAR_BUILT
# 1            0
# 12           0
# 13           0
# 14           0
# 15        2001

# %%
with open('../data/processed/0202_mpls_parcel_data_abr.pkl', 'wb') as picklefile:
    pickle.dump(df_subset, picklefile)
