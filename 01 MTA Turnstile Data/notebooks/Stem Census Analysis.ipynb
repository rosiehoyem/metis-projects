# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# import seaborn as sns

from IPython.display import Image

# enables inline plots, without it plots don't show up in the notebook
# %matplotlib inline

import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-22-ece81fc66046> in <module>()
#       9 get_ipython().magic('matplotlib inline')
#      10
# ---> 11 import seaborn as sns
#
# ImportError: No module named 'seaborn'

# %%
df = pd.read_csv('data/geo/subway_station_tracts.csv')
df1 = pd.read_csv('ACS_15_5YR_C24010/stem_women.csv')

# %%
df1.head()
# Out:
#    census_tract  count
# 0       2000100      0
# 1       2000200      0
# 2       2000400     22
# 3       2001600      0
# 4       2001900      4

# %%
df.head()
# Out:
#    OBJECTID_1  Join_Count  TARGET_FID  \
# 0           1           1           1
# 1           2           1           2
# 2           3           1           3
# 3           4           1           4
# 4           5           1           5
#
#                                                notes  \
# 0  4 nights, 6-all times, 6 Express-weekdays AM s...
# 1  4 nights, 6-all times, 6 Express-weekdays AM s...
# 2                              1-all times, 2-nights
# 3           4-nights, 3-all other times, 2-all times
# 4                        4-nights, 3-all other times
#
#                                  url              name  objectid  \
# 0  http://web.mta.info/nyct/service/          Astor Pl       1.0
# 1  http://web.mta.info/nyct/service/          Canal St       2.0
# 2  http://web.mta.info/nyct/service/           50th St       3.0
# 3  http://web.mta.info/nyct/service/         Bergen St       4.0
# 4  http://web.mta.info/nyct/service/  Pennsylvania Ave       5.0
#
# ...

# %%
df3 = pd.merge(df, df1, how='inner', right_on='census_tract', left_on='BoroCT2010')

# %%
df3.sample(5)
# Out:
#      OBJECTID_1  Join_Count  TARGET_FID  \
# 32           18           1          18
# 349         321           1         321
# 141          99           1          99
# 134         153           1         153
# 306         273           1         273
#
#                                                  notes  \
# 32   2-all times, 5-all times exc nights, skips rus...
# 349                                        D-all times
# 141                     A,S to Rockaway Park-all times
# 134                                        G-all times
# 306  2-all times, 5-rush hours AM southbound, PM no...
#
#                                    url                         name  objectid  \
# 32   http://web.mta.info/nyct/service/                   Freeman St      18.0
# 349  http://web.mta.info/nyct/service/                     20th Ave     321.0
# 141  http://web.mta.info/nyct/service/                Broad Channel      99.0
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 473 entries, 0 to 472
# Data columns (total 21 columns):
# OBJECTID_1      473 non-null int64
# Join_Count      473 non-null int64
# TARGET_FID      473 non-null int64
# notes           473 non-null object
# url             473 non-null object
# name            473 non-null object
# objectid        473 non-null float64
# line            473 non-null object
# CTLabel         473 non-null float64
# BoroCode        473 non-null int64
# BoroName        473 non-null object
# CT2010          473 non-null int64
# BoroCT2010      473 non-null int64
# CDEligibil      473 non-null object
# NTACode         473 non-null object
# NTAName         473 non-null object
# PUMA            473 non-null int64
# x               473 non-null float64
# y               473 non-null float64
# census_tract    473 non-null int64
# count           473 non-null int64
# dtypes: float64(4), int64(9), object(8)
# memory usage: 81.3+ KB

# %%
df3['count'].head(10)
# Out:
# 0    31
# 1    31
# 2    31
# 3    31
# 4    31
# 5    31
# 6    34
# 7    34
# 8    34
# 9    65
# Name: count, dtype: int64

# %%
women = pd.read_csv('ACS_15_5YR_C24010/stem_women_copy.csv')

# %%
clean_dashes = lambda x: re.sub(r'(\w*)(\s-\s)(\w*)',r'\1-\3', x)
women['name'] = women['name'].apply(clean_dashes)
