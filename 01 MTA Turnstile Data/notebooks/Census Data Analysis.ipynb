# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from IPython.display import Image

# enables inline plots, without it plots don't show up in the notebook
# %matplotlib inline

# %%
df = pd.read_csv('data/geo/subway_station_tracts.csv')
df1 = pd.read_csv('data/turnstile_160507 copy.txt')

# %%
capitalizer = lambda x: x.upper()
df['name'] = df['name'].apply(capitalizer)

clean_ave = lambda x: re.sub('AVE','AV', x)
df['name'] = df['name'].apply(clean_ave)

#.replace(to_replace=None, value=None, inplace=False, limit=None, regex=False)

df.replace('CONCOURSE', 'CONC', inplace=True)
df.replace('AVENUE', 'AV', inplace=True)
df.replace('WASHINGTON', 'WASH', inplace=True)
df.replace('JUNCTION', 'JCT', inplace=True)
df.replace('CONCOURSE', 'CONC', inplace=True)
df.replace('WOODHAVN', 'WOODHAVEN', inplace=True)
df.replace('CENTER', 'CTR', inplace=True)
df.replace('QUEENSBRIDGE', 'QNSBRIDGE', inplace=True)

# %%
# def clean_numbers(x):
#     matches = re.search(r'([\b\d+])([RD])', x)
#     for match in matches:
#         match.group(2) = ''

clean_numbers1 = lambda x: re.sub(r'(\b\d+)(RD\b)',r'\1', x)
df['name'] = df['name'].apply(clean_numbers1)

clean_numbers2 = lambda x: re.sub(r'(\b\d+)(TH\b)',r'\1', x)
df['name'] = df['name'].apply(clean_numbers2)

clean_numbers3 = lambda x: re.sub(r'(\b\d+)(ST\b)',r'\1', x)
df['name'] = df['name'].apply(clean_numbers3)

clean_numbers4 = lambda x: re.sub(r'(\b\d+)(ND\b)',r'\1', x)
df['name'] = df['name'].apply(clean_numbers4)

clean_dashes = lambda x: re.sub(r'(\w*)(\s-\s)(\w*)',r'\1-\3', x)
df['name'] = df['name'].apply(clean_dashes)

remove_parans = lambda x: re.sub(r'\(.*\)',r'', x)
df['name'] = df['name'].apply(remove_parans)

# %%
df1.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST   NQR456      BMT  04/30/2016  00:00:00
# 1  A002  R051  02-00-00   59 ST   NQR456      BMT  04/30/2016  04:00:00
# 2  A002  R051  02-00-00   59 ST   NQR456      BMT  04/30/2016  08:00:00
# 3  A002  R051  02-00-00   59 ST   NQR456      BMT  04/30/2016  12:00:00
# 4  A002  R051  02-00-00   59 ST   NQR456      BMT  04/30/2016  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  5639941
# 1  REGULAR  5639991
# 2  REGULAR  5640014
# 3  REGULAR  5640158
# 4  REGULAR  5640454
#
#    EXITS
# 0                                            1909983
# 1                                            1909993
# 2                                            1910024
# 3                                            1910134
# 4                                            1910197

# %%
df1.shape
# Out:
# (194466, 11)

# %%
df3 = pd.merge(df, df1, how='inner', left_on='name', right_on='STATION')

# %%
set(df1.STATION).difference(set(df.name))
# Out:
# {'103 ST-CORONA',
#  '116 ST-COLUMBIA',
#  '137 ST CITY COL',
#  '138/GRAND CONC',
#  '14 ST-UNION SQ',
#  '149/GRAND CONC',
#  '14TH STREET',
#  '15 ST-PROSPECT',
#  '161/YANKEE STAD',
#  '163 ST-AMSTERDM',
#  '2 AV',
#  '21 ST-QNSBRIDGE',
#  '3 AV 138 ST',
#  '33 ST-RAWSON ST',
#  '34 ST-HERALD SQ',
#  '34 ST-HUDSON YD',
#  '34 ST-PENN STA',
#  '40 ST LOWERY ST',
#  '42 ST-PORT AUTH',
#  '46 ST BLISS ST',
#  '47-50 STS ROCK',
#  '4AV-9 ST',
#  '5 AV/53 ST',
#  '5 AV/59 ST',
#  '5 AVE',
#  '57 ST-7 AV',
#  '59 ST COLUMBUS',
#  '61 ST WOODSIDE',
#  '66 ST-LINCOLN',
#  '68ST-HUNTER CO',
#  '75 ST-ELDERTS',
#  '81 ST-MUSEUM',
#  '82 ST-JACKSON H',
#  '85 ST-FOREST PK',
#  '90 ST-ELMHURST',
#  '9TH STREET',
#  'AQUEDUCT N.COND',
#  'AQUEDUCT RACETR',
#  'ASTORIA DITMARS',
#  'ATL AV-BARCLAY',
#  'AVENUE H',
#  'AVENUE I',
#  'AVENUE J',
#  'AVENUE M',
#  'AVENUE N',
#  'AVENUE P',
#  'AVENUE U',
#  'AVENUE X',
#  "B'WAY-LAFAYETTE",
#  'BAY PKWY',
#  'BEDFORD PK BLVD',
# ...

# %%
set(df.name).difference(set(df1.STATION))
# Out:
# {'103 ST-CORONA PLAZA',
#  '104-102 STS',
#  '116 ST-COLUMBIA UNIVERSITY',
#  '137 ST-CITY COLLEGE',
#  '138 ST-GRAND CONCOURSE',
#  '149 ST-GRAND CONCOURSE',
#  '15 ST-PROSPECT PARK',
#  '161 ST-YANKEE STADIUM',
#  '163 ST-AMSTERDAM AV',
#  '21 ST-QUEENSBRIDGE',
#  '3 AV-138 ST',
#  '34 ST-HUDSON YARDS',
#  '34 ST-PENN STATION',
#  '40 ST',
#  '42 ST-PORT AUTHORITY BUS TERM',
#  '47-50 STS-ROCKEFELLER CTR',
#  '5 AV-53 ST',
#  '5 AV-59 ST',
#  '5 AV-BRYANT PK',
#  '59 ST-COLUMBUS CIRCLE',
#  '62 ST',
#  '66 ST-LINCOLN CTR',
#  '68 ST-HUNTER COLLEGE',
#  '75 ST-ELDERT LN',
#  '81 ST',
#  '82 ST-JACKSON HTS',
#  '85 ST-FOREST PKY',
#  '90 ST-ELMHURST AV',
#  'AQUEDUCT RACETRACK',
#  'AQUEDUCT-NORTH CONDUIT AV',
#  'ASTORIA-DITMARS BLVD',
#  "ATLANTIC AV-BARCLAY'S CENTER",
#  'AV H',
#  'AV I',
#  'AV J',
#  'AV M',
#  'AV N',
#  'AV P',
#  'AV U',
#  'AV X',
#  'BAY PKY',
#  'BAY RIDGE-95 ST',
#  'BEDFORD PARK BLVD',
#  'BEDFORD PARK BLVD-LEHMAN COLLEGE',
#  'BEDFORD-NOSTRAND AVS',
# ...

# %%
df1.STATION.value_counts()
# Out:
# 34 ST-PENN STA     4957
# FULTON ST          4102
# 23 ST              3005
# GRD CNTRL-42 ST    2609
# CANAL ST           2477
# 34 ST-HERALD SQ    2331
# CHAMBERS ST        2267
# 86 ST              2204
# 42 ST-PORT AUTH    2198
# TIMES SQ-42 ST     2149
# 59 ST              2147
# WALL ST            2110
# ATL AV-BARCLAY     2025
# 125 ST             1819
# 14 ST              1804
# 59 ST COLUMBUS     1721
# CHURCH AV          1596
# 14 ST-UNION SQ     1592
# 50 ST              1570
# 161/YANKEE STAD    1562
# 28 ST              1554
# 96 ST              1553
# 47-50 STS ROCK     1541
# METS-WILLETS PT    1530
# JAY ST-METROTEC    1507
# LEXINGTON AV/53    1343
# CORTLANDT ST       1311
# BOWLING GREEN      1218
# BOROUGH HALL       1152
# FLUSHING-MAIN      1150
#                    ...
# CORTELYOU RD        126
# 25 AV               126
# 219 ST              126
# JUNIUS ST           126
# NORWOOD AV          126
# KINGSTON AV         126
# BAYCHESTER AV       126
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 181208 entries, 0 to 181207
# Data columns (total 39 columns):
# OBJECTID_1                                                              181208 non-null int64
# Join_Count                                                              181208 non-null int64
# TARGET_FID                                                              181208 non-null int64
# notes                                                                   181208 non-null object
# url                                                                     181208 non-null object
# name                                                                    181208 non-null object
# objectid                                                                181208 non-null float64
# line                                                                    181208 non-null object
# STATEFP                                                                 181208 non-null int64
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194466 entries, 0 to 194465
# Data columns (total 11 columns):
# C/A                                                                     194466 non-null object
# UNIT                                                                    194466 non-null object
# SCP                                                                     194466 non-null object
# STATION                                                                 194466 non-null object
# LINENAME                                                                194466 non-null object
# DIVISION                                                                194466 non-null object
# DATE                                                                    194466 non-null object
# TIME                                                                    194466 non-null object
# DESC                                                                    194466 non-null object
# ...

# %%
str = "W 4 ST-WASHINGTON SQ (LOWER)"
new_str = re.sub(r'\(.*\)',r'', str)
print(new_str)
match = re.search(r'\(.*\)', str)
print(match.group())
# Out:
# W 4 ST-WASHINGTON SQ
# (LOWER)
