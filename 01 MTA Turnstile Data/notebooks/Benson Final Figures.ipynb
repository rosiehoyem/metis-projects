# %% [markdown]
# # Benson Final Figures

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from IPython.display import Image

# enables inline plots, without it plots don't show up in the notebook
# %matplotlib inline

# %%
census = pd.read_csv('data/geo/top50_stations_women.csv')
census.head()
# Out:
#                          name   BoroName  BoroCT2010  stem_women
# 0  Roosevelt Island - Main St  Manhattan     1023801         354
# 1                     86th St  Manhattan     1017500         248
# 2                     72nd St  Manhattan     1012600         224
# 3                     28th St  Manhattan     1006800         200
# 4                     23rd St  Manhattan     1006800         200

# %%
census.sort_values('stem_women', ascending=False)
# Out:
#                                 name   BoroName  BoroCT2010  stem_women
# 0         Roosevelt Island - Main St  Manhattan     1023801         354
# 1                            86th St  Manhattan     1017500         248
# 2                            72nd St  Manhattan     1012600         224
# 3                            28th St  Manhattan     1006800         200
# 4                            23rd St  Manhattan     1006800         200
# 5          Cathedral Pkwy (110th St)  Manhattan     1019500         188
# 6                          Bergen St   Brooklyn     3006900         187
# 7                          Fulton St  Manhattan     1001502         184
# 8                            72nd St  Manhattan     1015900         172
# 9                            Wall St  Manhattan     1000700         171
# 10                          Broad St  Manhattan     1000700         171
# 11                 Hunters Point Ave     Queens     4000100         169
# 13                           14th St  Manhattan     1008100         165
# 12                           18th St  Manhattan     1008100         165
# 14                     Bowling Green  Manhattan     1001300         163
# 15                         Rector St  Manhattan     1001300         163
# 16                      Cortlandt St  Manhattan     1001300         163
# 17                          125th St  Manhattan     1021100         159
# 18                           96th St  Manhattan     1018300         154
# 19                    Greenpoint Ave   Brooklyn     3057500         151
# 20                           8th Ave  Manhattan     1007700         140
# 21                           96th St  Manhattan     1015601         136
# 22                          103rd St  Manhattan     1019100         135
# 23                          181st St  Manhattan     1027300         129
# 24                          116th St  Manhattan     1021800         127
# 25                           1st Ave  Manhattan     1003400         117
# 26                         Spring St  Manhattan     1004900         116
# 27  W 4th St - Washington Sq (Upper)  Manhattan     1006500         112
# 28  W 4th St - Washington Sq (Lower)  Manhattan     1006500         112
# 29                           96th St  Manhattan     1015801         109
# 30      Christopher St - Sheridan Sq  Manhattan     1007300         108
# 31                          75th Ave     Queens     4076901         107
# 32                           7th Ave   Brooklyn     3016100         105
# 33                           3rd Ave  Manhattan     1004000         105
# 34           Lexington Ave - 53rd St  Manhattan     1009800         101
# 35                      Nostrand Ave   Brooklyn     3031702         101
# 36                           6th Ave  Manhattan     1007100         100
# 37                           14th St  Manhattan     1007100         100
# 38                   4th Av - 9th St   Brooklyn     3013700          99
# 39                          145th St  Manhattan     1023100          98
# 40                           79th St  Manhattan     1016700          97
# 41                           23rd St  Manhattan     1005600          93
# 42                           28th St  Manhattan     1007600          93
# 43                        Dyckman St  Manhattan     1028300          93
# 44               Herald Sq - 34th St  Manhattan     1007600          93
# 45                           21st St     Queens     4000700          93
# 46                Court Sq - 23rd St     Queens     4000700          93
# 47                           33rd St  Manhattan     1007200          93
# 48         Vernon Blvd - Jackson Ave     Queens     4000700          93
# 49                          67th Ave     Queens     4071306          91

# %%
ts = pd.read_csv('volumeByStation.csv')

# %%
ts = ts.sort_values('TotalVol', ascending=False)[:51]

# %%
ts['ts_rank']=ts.index + 1
ts.head(10).to_json("ts_json.txt", orient="records")
ts.head()
# Out:
#            STATION        ENTRIES          EXITS  diffEntries  diffExits  \
# 0   34 ST-PENN STA   488881015020   287627882120    4206635.0  3584248.0
# 1  GRD CNTRL-42 ST   744724963097   146796271108    3584257.0  3203623.0
# 2  34 ST-HERALD SQ   563482244287   596750042788    3026299.0  2719583.0
# 3            23 ST  1111704579992  1034681559184    2922280.0  2239758.0
# 4            86 ST   394240269476   430100768929    2819901.0  2316859.0
#
#    machine_change  counterReset   TotalVol  ts_rank
# 0           100.0           0.0  7790883.0        1
# 1            61.0           0.0  6787880.0        2
# 2            54.0           0.0  5745882.0        3
# 3            71.0           0.0  5162038.0        4
# 4            52.0           0.0  5136760.0        5

# %%
census['census_rank']=census.index + 1
census.head(10).to_json("census_json.txt", orient="records")
census.head()
# Out:
#                        name   BoroName  BoroCT2010  stem_women  census_rank
# 0  ROOSEVELT ISLAND-MAIN ST  Manhattan     1023801         354            1
# 1                     86 ST  Manhattan     1017500         248            2
# 2                     72 ST  Manhattan     1012600         224            3
# 3                     28 ST  Manhattan     1006800         200            4
# 4                     23 ST  Manhattan     1006800         200            5

# %%
import re

capitalizer = lambda x: x.upper()
census['name'] = census['name'].apply(capitalizer)

clean_ave = lambda x: re.sub('AVE','AV', x)
census['name'] = census['name'].apply(clean_ave)

clean_numbers1 = lambda x: re.sub(r'(\b\d+)(RD\b)',r'\1', x)
census['name'] = census['name'].apply(clean_numbers1)

clean_numbers2 = lambda x: re.sub(r'(\b\d+)(TH\b)',r'\1', x)
census['name'] = census['name'].apply(clean_numbers2)

clean_numbers3 = lambda x: re.sub(r'(\b\d+)(ST\b)',r'\1', x)
census['name'] = census['name'].apply(clean_numbers3)

clean_numbers4 = lambda x: re.sub(r'(\b\d+)(ND\b)',r'\1', x)
census['name'] = census['name'].apply(clean_numbers4)

clean_dashes = lambda x: re.sub(r'(\w*)(\s-\s)(\w*)',r'\1-\3', x)
census['name'] = census['name'].apply(clean_dashes)

remove_parans = lambda x: re.sub(r'\(.*\)',r'', x)
census['name'] = census['name'].apply(remove_parans)

census.replace('CONCOURSE', 'CONC', inplace=True)
census.replace('AVENUE', 'AV', inplace=True)
census.replace('WASHINGTON', 'WASH', inplace=True)
census.replace('JUNCTION', 'JCT', inplace=True)
census.replace('CONCOURSE', 'CONC', inplace=True)
census.replace('WOODHAVN', 'WOODHAVEN', inplace=True)
census.replace('CENTER', 'CTR', inplace=True)
census.replace('QUEENSBRIDGE', 'QNSBRIDGE', inplace=True)
census.replace('W 4 ST-WASHINGTON SQ ', 'W 4 ST-WASH SQ', inplace=True)

# %%
set(ts.STATION).difference(set(census.name))
# Out:
# {'14 ST-UNION SQ',
#  '161/YANKEE STAD',
#  '34 ST-HERALD SQ',
#  '34 ST-PENN STA',
#  '42 ST-BRYANT PK',
#  '42 ST-PORT AUTH',
#  '47-50 STS ROCK',
#  '49 ST',
#  '5 AV/53 ST',
#  '50 ST',
#  '59 ST',
#  '59 ST COLUMBUS',
#  '66 ST-LINCOLN',
#  '68ST-HUNTER CO',
#  '77 ST',
#  'ATL AV-BARCLAY',
#  "B'WAY-LAFAYETTE",
#  'BEDFORD AV',
#  'BOROUGH HALL',
#  'CANAL ST',
#  'CHAMBERS ST',
#  'CHURCH AV',
#  'CROWN HTS-UTICA',
#  'DELANCEY/ESSEX',
#  'FLUSHING-MAIN',
#  'GRAND ST',
#  'GRD CNTRL-42 ST',
#  'JAMAICA CENTER',
#  'JAY ST-METROTEC',
#  'JKSN HT-ROOSVLT',
#  'KEW GARDENS',
#  'KINGS HWY',
#  'LEXINGTON AV/53',
#  'PATH WTC',
#  'TIMES SQ-42 ST'}

# %%
set(census.name).difference(set(ts.STATION))
# Out:
# {'1 AV',
#  '103 ST',
#  '18 ST',
#  '181 ST',
#  '21 ST',
#  '3 AV',
#  '4 AV-9 ST',
#  '6 AV',
#  '67 AV',
#  '75 AV',
#  '79 ST',
#  'BERGEN ST',
#  'BROAD ST',
#  'CATHEDRAL PKWY ',
#  'CHRISTOPHER ST-SHERIDAN SQ',
#  'CORTLANDT ST',
#  'COURT SQ-23 ST',
#  'DYCKMAN ST',
#  'GREENPOINT AV',
#  'HERALD SQ-34 ST',
#  'HUNTERS POINT AV',
#  'LEXINGTON AV-53 ST',
#  'NOSTRAND AV',
#  'RECTOR ST',
#  'ROOSEVELT ISLAND-MAIN ST',
#  'SPRING ST',
#  'VERNON BLVD-JACKSON AV'}

# %%
census_ts = pd.merge(census, ts, how='inner', left_on='name', right_on='STATION')

# %%
census_ts
# Out:
#               name   BoroName  BoroCT2010  stem_women  census_rank  \
# 0            86 ST  Manhattan     1017500         248            2
# 1            72 ST  Manhattan     1012600         224            3
# 2            72 ST  Manhattan     1015900         172            9
# 3            28 ST  Manhattan     1006800         200            4
# 4            28 ST  Manhattan     1007600          93           43
# 5            23 ST  Manhattan     1006800         200            5
# 6            23 ST  Manhattan     1005600          93           42
# 7        FULTON ST  Manhattan     1001502         184            8
# 8          WALL ST  Manhattan     1000700         171           10
# 9            14 ST  Manhattan     1008100         165           14
# 10           14 ST  Manhattan     1007100         100           38
# 11   BOWLING GREEN  Manhattan     1001300         163           15
# 12          125 ST  Manhattan     1021100         159           18
# 13           96 ST  Manhattan     1018300         154           19
# 14           96 ST  Manhattan     1015601         136           22
# 15           96 ST  Manhattan     1015801         109           30
# 16            8 AV  Manhattan     1007700         140           21
# 17          116 ST  Manhattan     1021800         127           25
# 18  W 4 ST-WASH SQ  Manhattan     1006500         112           28
# 19  W 4 ST-WASH SQ  Manhattan     1006500         112           29
# 20            7 AV   Brooklyn     3016100         105           33
# 21          145 ST  Manhattan     1023100          98           40
# 22           33 ST  Manhattan     1007200          93           48
#
#            STATION        ENTRIES          EXITS  diffEntries  diffExits  \
# 0            86 ST   394240269476   430100768929    2819901.0  2316859.0
# 1            72 ST   486479372196   495763311658    1332604.0  1120278.0
# 2            72 ST   486479372196   495763311658    1332604.0  1120278.0
# 3            28 ST   270514360108   370396202879    1268782.0  1168521.0
# 4            28 ST   270514360108   370396202879    1268782.0  1168521.0
# 5            23 ST  1111704579992  1034681559184    2922280.0  2239758.0
# 6            23 ST  1111704579992  1034681559184    2922280.0  2239758.0
# 7        FULTON ST   681257714035   716552976737    1975340.0  1646421.0
# 8          WALL ST   109893944939    64151806881    1159578.0  1003801.0
# 9            14 ST   306370186244   287405232321    1576798.0  1331791.0
# 10           14 ST   306370186244   287405232321    1576798.0  1331791.0
# 11   BOWLING GREEN   342782077081   294405257719     778546.0   689942.0
# 12          125 ST  1176230513723   668521913609    1949865.0  1607660.0
# 13           96 ST   133463825976   239594572257    1929079.0  1286849.0
# 14           96 ST   133463825976   239594572257    1929079.0  1286849.0
# 15           96 ST   133463825976   239594572257    1929079.0  1286849.0
# 16            8 AV    34274371066    15985260955    1061633.0   708792.0
# 17          116 ST   288129306997   348630664475     952916.0   472831.0
# 18  W 4 ST-WASH SQ   141430866025   151138506679    1146148.0  1087478.0
# 19  W 4 ST-WASH SQ   141430866025   151138506679    1146148.0  1087478.0
# 20            7 AV   620654076856   181185011422     959529.0   743093.0
# 21          145 ST   250335187372   354170333562     985871.0   801362.0
# 22           33 ST    58976487427    23541320106     776539.0   605691.0
#
#     machine_change  counterReset   TotalVol  ts_rank
# 0             52.0           0.0  5136760.0        5
# 1             25.0           0.0  2452882.0       19
# 2             25.0           0.0  2452882.0       19
# 3             37.0           0.0  2437303.0       20
# 4             37.0           0.0  2437303.0       20
# 5             71.0           0.0  5162038.0        4
# 6             71.0           0.0  5162038.0        4
# 7             96.0           0.0  3621761.0        9
# 8             50.0           0.0  2163379.0       24
# 9             43.0           0.0  2908589.0       16
# 10            43.0           0.0  2908589.0       16
# 11            29.0           0.0  1468488.0       38
# 12            43.0           0.0  3557525.0       11
# 13            37.0           0.0  3215928.0       13
# 14            37.0           0.0  3215928.0       13
# 15            37.0           0.0  3215928.0       13
# 16            18.0           0.0  1770425.0       31
# 17            22.0           0.0  1425747.0       39
# 18            19.0           0.0  2233626.0       23
# 19            19.0           0.0  2233626.0       23
# 20            23.0           0.0  1702622.0       33
# 21            19.0           0.0  1787233.0       30
# 22            22.0           0.0  1382230.0       41

# %%
census_ts['comb_rank'] = census_ts['ts_rank'] + census_ts['census_rank']
# census_ts.to_csv

# %%
data_final = census_ts.sort_values('comb_rank', ascending=True)
data_final.head(10).to_json("census_ts_json.txt", orient="records")
data_final.head()
# Out:
#         name   BoroName  BoroCT2010  stem_women  census_rank    STATION  \
# 0      86 ST  Manhattan     1017500         248            2      86 ST
# 5      23 ST  Manhattan     1006800         200            5      23 ST
# 7  FULTON ST  Manhattan     1001502         184            8  FULTON ST
# 1      72 ST  Manhattan     1012600         224            3      72 ST
# 3      28 ST  Manhattan     1006800         200            4      28 ST
#
#          ENTRIES          EXITS  diffEntries  diffExits  machine_change  \
# 0   394240269476   430100768929    2819901.0  2316859.0            52.0
# 5  1111704579992  1034681559184    2922280.0  2239758.0            71.0
# 7   681257714035   716552976737    1975340.0  1646421.0            96.0
# 1   486479372196   495763311658    1332604.0  1120278.0            25.0
# 3   270514360108   370396202879    1268782.0  1168521.0            37.0
#
#    counterReset   TotalVol  ts_rank  comb_rank
# 0           0.0  5136760.0        5          7
# 5           0.0  5162038.0        4          9
# 7           0.0  3621761.0        9         17
# 1           0.0  2452882.0       19         22
# 3           0.0  2437303.0       20         24

# %%
census_ts.plot.scatter('stem_women', 'TotalVol');

# %%
import seaborn as sns
# Out:
# /Users/rosiehoyem/anaconda2/envs/py35/lib/python3.5/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
sns.lmplot('stem_women', 'TotalVol', data=final, hue='STATION', fit_reg=False);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-b44a1e70dd5b> in <module>()
# ----> 1 sns.lmplot('stem_women', 'TotalVol', data=final, hue='STATION', fit_reg=False);
#
# NameError: name 'final' is not defined

# %%
final = census_ts.sort_values('comb_rank', ascending=True)
final
